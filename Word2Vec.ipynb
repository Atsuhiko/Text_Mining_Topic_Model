# %% [markdown]
# # Word2Vec

# %% [markdown]
# ### Word2Vecに関する参考：https://qiita.com/makaishi2/items/63b7986f6da93dc55edd, https://qiita.com/juri-t/items/22055e264c4970c1ed75

# %% [markdown]
# ## モジュールの設定とデータのインポート

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# NLP
import glob
from tqdm import tqdm
import math
import urllib
import gensim
from gensim import corpora
from collections import defaultdict

# Word2Vecライブラリのロード
from gensim.models import word2vec

import os
import gc
import logging
import pickle
from smart_open import open
print(os.listdir("../data"))

# Any results you write to the current directory are saved as output.
# Out:
# ['glove6b50d', 'imagesforkernal', 'sample_submission.csv', 'stopwords-en.txt', 'submission.csv', 'test.csv', 'test_labels.csv', 'train.csv']

# %%
# importing the dataset
train=pd.read_csv("../data/train.csv")

# importing stopwords
f = open('../data/stopwords-en.txt',encoding='utf-8_sig') #encoding='utf-8_sig'を追加
stopword = f.read()
f.close()

# %% [markdown]
# ## 前処理

# %% [markdown]
# #### シンボルの除去

# %%
# It takes some time.
# setting symbols
symbols = '.,?!-;*"…:—()%#$&_/@＼・ω+=”“[]^–>\\°<~•≠™ˈʊɒ∞§{}·τα❤☺ɡ|¢→̶`❥━┣┫┗Ｏ►★©―ɪ✔®\x96\x92●£♥➤´¹☕≈÷♡◐║▬′ɔː€۩۞†μ✒➥═☆ˌ◄½ʻπδηλσερνʃ✬ＳＵＰＥＲＩＴ☻±♍µº¾✓◾؟．⬅℅»Вав❣⋅¿¬♫ＣＭβ█▓▒░⇒⭐›¡₂₃❧▰▔◞▀▂▃▄▅▆▇↙γ̄″☹➡«φ⅓„✋：¥̲̅́∙‛◇✏▷❓❗¶˚˙）сиʿ✨。ɑ\x80◕！％¯−ﬂﬁ₁²ʌ¼⁴⁄₄⌠♭✘╪▶☭✭♪☔☠♂☃☎✈✌✰❆☙○‣⚓年∎ℒ▪▙☏⅛ｃａｓǀ℮¸ｗ‚∼‖ℳ❄←☼⋆ʒ⊂、⅔¨͡๏⚾⚽Φ×θ￦？（℃⏩☮⚠月✊❌⭕▸■⇌☐☑⚡☄ǫ╭∩╮，例＞ʕɐ̣Δ₀✞┈╱╲▏▕┃╰▊▋╯┳┊≥☒↑☝ɹ✅☛♩☞ＡＪＢ◔◡↓♀⬆̱ℏ\x91⠀ˤ╚↺⇤∏✾◦♬³の｜／∵∴√Ω¤☜▲↳▫‿⬇✧ｏｖｍ－２０８＇‰≤∕ˆ⚜☁\n🍕\r🐵😑\xa0\ue014\t\uf818\uf04a\xad😢🐶️\uf0e0😜😎👊\u200b\u200e😁عدويهصقأناخلىبمغر😍💖💵Е👎😀😂\u202a\u202c🔥😄🏻💥ᴍʏʀᴇɴᴅᴏᴀᴋʜᴜʟᴛᴄᴘʙғᴊᴡɢ😋👏שלוםבי😱‼\x81エンジ故障\u2009🚌ᴵ͞🌟😊😳😧🙀😐😕\u200f👍😮😃😘אעכח💩💯⛽🚄🏼ஜ😖ᴠ🚲‐😟😈💪🙏🎯🌹😇💔😡\x7f👌ἐὶήιὲκἀίῃἴξ🙄Ｈ😠\ufeff\u2028😉😤⛺🙂\u3000تحكسة👮💙فزط😏🍾🎉😞\u2008🏾😅😭👻😥😔😓🏽🎆🍻🍽🎶🌺🤔😪\x08‑🐰🐇🐱🙆😨🙃💕𝘊𝘦𝘳𝘢𝘵𝘰𝘤𝘺𝘴𝘪𝘧𝘮𝘣💗💚地獄谷улкнПоАН🐾🐕😆ה🔗🚽歌舞伎🙈😴🏿🤗🇺🇸мυтѕ⤵🏆🎃😩\u200a🌠🐟💫💰💎эпрд\x95🖐🙅⛲🍰🤐👆🙌\u2002💛🙁👀🙊🙉\u2004ˢᵒʳʸᴼᴷᴺʷᵗʰᵉᵘ\x13🚬🤓\ue602😵άοόςέὸתמדףנרךצט😒͝🆕👅👥👄🔄🔤👉👤👶👲🔛🎓\uf0b7\uf04c\x9f\x10成都😣⏺😌🤑🌏😯ех😲Ἰᾶὁ💞🚓🔔📚🏀👐\u202d💤🍇\ue613小土豆🏡❔⁉\u202f👠》कर्मा🇹🇼🌸蔡英文🌞🎲レクサス😛外国人关系Сб💋💀🎄💜🤢َِьыгя不是\x9c\x9d🗑\u2005💃📣👿༼つ༽😰ḷЗз▱ц￼🤣卖温哥华议会下降你失去所有的钱加拿大坏税骗子🐝ツ🎅\x85🍺آإشء🎵🌎͟ἔ油别克🤡🤥😬🤧й\u2003🚀🤴ʲшчИОРФДЯМюж😝🖑ὐύύ特殊作戦群щ💨圆明园קℐ🏈😺🌍⏏ệ🍔🐮🍁🍆🍑🌮🌯🤦\u200d𝓒𝓲𝓿𝓵안영하세요ЖљКћ🍀😫🤤ῦ我出生在了可以说普通话汉语好极🎼🕺🍸🥂🗽🎇🎊🆘🤠👩🖒🚪天一家⚲\u2006⚭⚆⬭⬯⏖新✀╌🇫🇷🇩🇪🇮🇬🇧😷🇨🇦ХШ🌐\x1f杀鸡给猴看ʁ𝗪𝗵𝗲𝗻𝘆𝗼𝘂𝗿𝗮𝗹𝗶𝘇𝗯𝘁𝗰𝘀𝘅𝗽𝘄𝗱📺ϖ\u2000үսᴦᎥһͺ\u2007հ\u2001ɩｙｅ൦ｌƽｈ𝐓𝐡𝐞𝐫𝐮𝐝𝐚𝐃𝐜𝐩𝐭𝐢𝐨𝐧Ƅᴨןᑯ໐ΤᏧ௦Іᴑ܁𝐬𝐰𝐲𝐛𝐦𝐯𝐑𝐙𝐣𝐇𝐂𝐘𝟎ԜТᗞ౦〔Ꭻ𝐳𝐔𝐱𝟔𝟓𝐅🐋ﬃ💘💓ё𝘥𝘯𝘶💐🌋🌄🌅𝙬𝙖𝙨𝙤𝙣𝙡𝙮𝙘𝙠𝙚𝙙𝙜𝙧𝙥𝙩𝙪𝙗𝙞𝙝𝙛👺🐷ℋ𝐀𝐥𝐪🚶𝙢Ἱ🤘ͦ💸ج패티Ｗ𝙇ᵻ👂👃ɜ🎫\uf0a7БУі🚢🚂ગુજરાતીῆ🏃𝓬𝓻𝓴𝓮𝓽𝓼☘﴾̯﴿₽\ue807𝑻𝒆𝒍𝒕𝒉𝒓𝒖𝒂𝒏𝒅𝒔𝒎𝒗𝒊👽😙\u200cЛ‒🎾👹⎌🏒⛸公寓养宠物吗🏄🐀🚑🤷操美𝒑𝒚𝒐𝑴🤙🐒欢迎来到阿拉斯ספ𝙫🐈𝒌𝙊𝙭𝙆𝙋𝙍𝘼𝙅ﷻ🦄巨收赢得白鬼愤怒要买额ẽ🚗🐳𝟏𝐟𝟖𝟑𝟕𝒄𝟗𝐠𝙄𝙃👇锟斤拷𝗢𝟳𝟱𝟬⦁マルハニチロ株式社⛷한국어ㄸㅓ니͜ʖ𝘿𝙔₵𝒩ℯ𝒾𝓁𝒶𝓉𝓇𝓊𝓃𝓈𝓅ℴ𝒻𝒽𝓀𝓌𝒸𝓎𝙏ζ𝙟𝘃𝗺𝟮𝟭𝟯𝟲👋🦊多伦🐽🎻🎹⛓🏹🍷🦆为和中友谊祝贺与其想象对法如直接问用自己猜本传教士没积唯认识基督徒曾经让相信耶稣复活死怪他但当们聊些政治题时候战胜因圣把全堂结婚孩恐惧且栗谓这样还♾🎸🤕🤒⛑🎁批判检讨🏝🦁🙋😶쥐스탱트뤼도석유가격인상이경제황을렵게만들지않록잘관리해야합다캐나에서대마초와화약금의품런성분갈때는반드시허된사용🔫👁凸ὰ💲🗯𝙈Ἄ𝒇𝒈𝒘𝒃𝑬𝑶𝕾𝖙𝖗𝖆𝖎𝖌𝖍𝖕𝖊𝖔𝖑𝖉𝖓𝖐𝖜𝖞𝖚𝖇𝕿𝖘𝖄𝖛𝖒𝖋𝖂𝕴𝖟𝖈𝕸👑🚿💡知彼百\uf005𝙀𝒛𝑲𝑳𝑾𝒋𝟒😦𝙒𝘾𝘽🏐𝘩𝘨ὼṑ𝑱𝑹𝑫𝑵𝑪🇰🇵👾ᓇᒧᔭᐃᐧᐦᑳᐨᓃᓂᑲᐸᑭᑎᓀᐣ🐄🎈🔨🐎🤞🐸💟🎰🌝🛳点击查版🍭𝑥𝑦𝑧ＮＧ👣\uf020っ🏉ф💭🎥Ξ🐴👨🤳🦍\x0b🍩𝑯𝒒😗𝟐🏂👳🍗🕉🐲چی𝑮𝗕𝗴🍒ꜥⲣⲏ🐑⏰鉄リ事件ї💊「」\uf203\uf09a\uf222\ue608\uf202\uf099\uf469\ue607\uf410\ue600燻製シ虚偽屁理屈Г𝑩𝑰𝒀𝑺🌤𝗳𝗜𝗙𝗦𝗧🍊ὺἈἡχῖΛ⤏🇳𝒙ψՁմեռայինրւդձ冬至ὀ𝒁🔹🤚🍎𝑷🐂💅𝘬𝘱𝘸𝘷𝘐𝘭𝘓𝘖𝘹𝘲𝘫کΒώ💢ΜΟΝΑΕ🇱♲𝝈↴💒⊘Ȼ🚴🖕🖤🥘📍👈➕🚫🎨🌑🐻𝐎𝐍𝐊𝑭🤖🎎😼🕷ｇｒｎｔｉｄｕｆｂｋ𝟰🇴🇭🇻🇲𝗞𝗭𝗘𝗤👼📉🍟🍦🌈🔭《🐊🐍\uf10aლڡ🐦\U0001f92f\U0001f92a🐡💳ἱ🙇𝗸𝗟𝗠𝗷🥜さようなら🔼'

# deleate symbols
def basic_preprocess(data):
    data = str(data)
    data = data.lower()
    '''
    Credit goes to https://www.kaggle.com/gpreda/jigsaw-fast-compact-solution
    '''
    punct =  "/-'?!.,#$%\'()*+-/:;<=>@[\\]^_`{|}~`" + '""“”’' + '∞θ÷α•à−β∅³π‘₹´°£€\×™√²—–&' + symbols
    def clean_special_chars(text, punct):        
        for p in punct:
            text = text.replace(p, ' ')
        return text

    data = clean_special_chars(data, punct)
    return data

train['cleaned'] = train['comment_text'].apply(basic_preprocess)

# %% [markdown]
# #### ストップワードとして定義した単語を除外

# %%
#list
all_text = list(train['cleaned'])

# filter stopwords
stop_words = set(stopword.split())
texts = [[word for word in document.lower().split() if word not in stop_words] for document in all_text]

# reduce memory
del train
del all_text
gc.collect()
# Out:
# 0

# %%
# setting frequency
frequency = defaultdict(int)

# count the number of occurrences of the word
for text in texts:
    for token in text:
        frequency[token] += 1

# build only words above 100 into an array
texts = [[token for token in text if frequency[token] > 100] for text in texts]

# save texts
#with open("texts.pkl",'wb') as f:
#    pickle.dump(texts,f)

# %%
texts
# Out:
# [['explanation',
#   'edits',
#   'username',
#   'hardcore',
#   'fan',
#   'reverted',
#   'gas',
#   'voted',
#   'york',
#   'fac',
#   'remove',
#   'template',
#   'talk',
#   'retired',
#   '89',
#   '205',
#   '38',
#   '27'],
#  ['matches',
#   'background',
#   'colour',
#   'seemingly',
#   'stuck',
#   'talk',
#   '21',
#   '51',
#   'january',
#   '11',
#   'utc'],
#  ['hey',
#   'edit',
#   'war',
#   'guy',
#   'constantly',
#   'removing',
#   'relevant',
#   'talking',
#   'edits',
#   'talk',
#   'care',
#   'formatting',
#   'actual',
#   'info'],
#  ['real',
#   'suggestions',
#   'improvement',
#   'wondered',
#   'statistics',
#   'subsection',
#   'types',
#   'references',
#   'exact',
#   'format',
#   'format',
#   'preferences',
#   'formatting',
#   'style',
#   'references',
#   'appears',
#   'backlog',
#   'articles',
#   'review',
#   'guess',
#   'delay',
#   'reviewer',
#   'listed',
#   'relevant',
#   'form',
#   'wikipedia',
#   'article',
#   'nominations',
#   'transport'],
#  ['sir', 'hero', 'chance', 'remember'],
#  ['congratulations', 'tools', 'talk'],
#  ['cocksucker', 'piss'],
#  ['vandalism', 'matt', 'article', 'reverted', 'banned'],
#  ['word',
#   'nonsense',
#   'offensive',
#   'write',
#   'article',
#   'wow',
#   'jump',
#   'vandalism',
#   'requesting',
#   'encyclopedic',
#   'school',
#   'reference',
#   'selective',
#   'stub',
#   'animal',
#   'short',
#   'article',
#   'info',
#   'expertise',
#   '93',
#   '161',
#   '107',
#   '169'],
#  ['subject', 'contrary'],
#  ['fair',
#   'rationale',
#   'image',
#   'jpg',
#   'uploading',
#   'image',
#   'jpg',
#   'notice',
#   'image',
#   'specifies',
#   'image',
#   'fair',
#   'explanation',
#   'rationale',
#   'wikipedia',
#   'articles',
#   'constitutes',
#   'fair',
#   'addition',
#   'fair',
#   'template',
#   'write',
#   'image',
#   'description',
#   'specific',
#   'explanation',
#   'rationale',
#   'image',
#   'article',
#   'consistent',
#   'fair',
#   'image',
#   'description',
#   'edit',
#   'include',
#   'fair',
#   'rationale',
#   'uploaded',
#   'fair',
#   'media',
#   'checking',
#   'fair',
#   'rationale',
#   'list',
#   'image',
#   'edited',
#   'clicking',
#   'contributions',
#   'link',
#   'located',
#   'wikipedia',
#   'logged',
#   'selecting',
#   'image',
#   'dropdown',
#   'box',
#   'note',
#   'fair',
#   'images',
#   'uploaded',
#   '4',
#   '2006',
#   'lacking',
#   'explanation',
#   'deleted',
#   'week',
#   'uploaded',
#   'criteria',
#   'speedy',
#   'deletion',
#   'questions',
#   'media',
#   'copyright',
#   'questions',
#   'talk',
#   'contribs',
#   'source',
#   'image',
#   'jpg',
#   'uploading',
#   'image',
#   'jpg',
#   'noticed',
#   'file',
#   'description',
#   'created',
#   'content',
#   'copyright',
#   'status',
#   'unclear',
#   'create',
#   'file',
#   'owner',
#   'copyright',
#   'link',
#   'terms',
#   'content',
#   'sufficient',
#   'copyright',
#   'holder',
#   'publisher',
#   'copyright',
#   'acknowledged',
#   'adding',
#   'source',
#   'add',
#   'proper',
#   'copyright',
#   'licensing',
#   'tag',
#   'file',
#   'created',
#   'picture',
#   'audio',
#   'video',
#   'tag',
#   'release',
#   'gfdl',
#   'media',
#   'meets',
#   'criteria',
#   'wikipedia',
#   'fair',
#   'tag',
#   'tags',
#   'listed',
#   'wikipedia',
#   'image',
#   'copyright',
#   'tags',
#   'fair',
#   'wikipedia',
#   'image',
#   'copyright',
#   'tags',
#   'list',
#   'copyright',
#   'tags',
#   'uploaded',
#   'files',
#   'checking',
#   'source',
#   'tagged',
#   'list',
#   'files',
#   'uploaded',
#   'link',
#   'unsourced',
#   'untagged',
#   'images',
#   'deleted',
#   'week',
#   'tagged',
#   'criteria',
#   'speedy',
#   'deletion',
#   'image',
#   'copyrighted',
#   'license',
#   'wikipedia',
#   'fair',
#   'image',
#   'deleted',
#   '48',
#   'hours',
#   'questions',
#   'media',
#   'copyright',
#   'questions',
#   'talk',
#   'contribs'],
#  ['discuss', 'phone'],
#  ['hey',
#   'talk',
#   'exclusive',
#   'wp',
#   'destroying',
#   'appointed',
#   'gang',
#   'questions',
#   'anti',
#   'social',
#   'destructive',
#   'contribution',
#   'wp',
#   'clean',
#   'behavior',
#   'issue',
#   'warnings'],
#  ['start',
#   'throwing',
#   'accusations',
#   'warnings',
#   'review',
#   'edit',
#   'hominem',
#   'attacks',
#   'argument',
#   'abusing',
#   'power',
#   'admin',
#   'edit',
#   'relevant',
#   'single',
#   'talked',
#   'event',
#   'news',
#   'late',
#   'absence',
#   'notable',
#   'living',
#   'president',
#   'attend',
#   'notable',
#   'intend',
#   'revert',
#   'edit',
#   'hopes',
#   'attention',
#   'admin',
#   'issue',
#   'throw',
#   'accusations',
#   'achieve',
#   'level',
#   'civility',
#   'rational',
#   'discussion',
#   'topic',
#   'resolve',
#   'matter'],
#  ['girl',
#   'started',
#   'arguments',
#   'stuck',
#   'nose',
#   'belong',
#   'argument',
#   'situation',
#   'settled',
#   'apologized'],
#  ['age',
#   '2002',
#   '18',
#   'february',
#   '18th',
#   '19',
#   'songs',
#   'signed',
#   'label',
#   '2003',
#   '20',
#   'coming',
#   'singles',
#   'town',
#   'born',
#   '1983',
#   'banks',
#   '22',
#   'birthday',
#   'passed',
#   '23',
#   '1983',
#   '2006',
#   'death',
#   'god',
#   'thinking',
#   '23',
#   'changing',
#   'birth',
#   'god'],
#  ['bye'],
#  ['redirect', 'talk', 'pop'],
#  ['sense', 'argue', 'include', 'hindi', 'include'],
#  ['bother',
#   'writing',
#   'removing',
#   'posted',
#   'discuss',
#   'closer',
#   'wrestling',
#   'deaths',
#   'listed',
#   'surely',
#   'belong'],
#  ['edits',
#   'read',
#   'wp',
#   'editing',
#   'film',
#   'articles',
#   'edits',
#   'simply',
#   'unnecessary',
#   'details',
#   'bad',
#   'writing',
#   'damage',
#   '45'],
#  ['yeah', 'studying'],
#  ['stated',
#   'arms',
#   'assertion',
#   'simply',
#   'true',
#   'common',
#   'variety',
#   'myths',
#   'myths',
#   'decent',
#   'forgive',
#   'edit'],
#  ['signpost', '24', 'september', '2012', 'read', 'signpost', 'single'],
#  ['1st',
#   'paragraph',
#   'edit',
#   'understand',
#   'reasons',
#   'edit',
#   'article',
#   'data',
#   'wrong',
#   'strategy',
#   'introducing',
#   'academic',
#   'paragraph',
#   'unhelpful',
#   'approach',
#   'specific',
#   'subject',
#   'note',
#   'articles',
#   'sitting',
#   'improvement',
#   'support',
#   'view',
#   'edit',
#   'reverted',
#   'invite',
#   'visit',
#   'articles',
#   'written',
#   'a1',
#   'learned',
#   'hand',
#   'john',
#   'john',
#   'question',
#   'current',
#   'version',
#   'wikipedia',
#   'article',
#   'pair',
#   'improved',
#   'academic',
#   'credentials',
#   'paragraph',
#   'helps',
#   'repeat',
#   'argument',
#   'law',
#   'suggests',
#   'harvard',
#   'law',
#   'avoided',
#   'learning',
#   'managed',
#   'grasp',
#   'processes',
#   'judging',
#   'hope',
#   'illustrates',
#   'stronger',
#   'argument',
#   'thomas',
#   'mentions',
#   'return',
#   'law',
#   'degree',
#   'minimum',
#   'questioning',
#   'edit',
#   'deserves'],
#  ['included'],
#  ['apologize',
#   'wikipedia',
#   'article',
#   'knowledge',
#   'subject',
#   'sources',
#   'history',
#   'studies',
#   'studies',
#   'guess',
#   'scan',
#   'mail',
#   'translate'],
#  ['mother',
#   'child',
#   'michael',
#   'jackson',
#   'studied',
#   'motives',
#   'character',
#   'ignore',
#   'continue',
#   'bullshit',
#   'jayjg',
#   'throwing',
#   '18',
#   '01',
#   '16',
#   'jun',
#   '2005',
#   'utc'],
#  ['bit', 'picture', 'base', 'duck'],
#  ['barnstar', 'real', 'life', 'barnstar', 'stars'],
#  ['post', 'block', 'expires', 'funny', 'uncivil'],
#  ['heading', 'fight', 'freedom'],
#  ['praise', 'looked', 'article', '6', 'months', 'improved'],
#  ['post',
#   'list',
#   'file',
#   'hard',
#   'drive',
#   'meaning',
#   'updating',
#   'sound',
#   'list',
#   'time',
#   'spent',
#   'freely',
#   'licensed',
#   'classical',
#   'music',
#   'attempts',
#   'failed',
#   'effectively',
#   'classical',
#   'music',
#   'wikiproject',
#   'wikipedia',
#   'talk',
#   'wikiproject',
#   'classical',
#   'music',
#   'archive',
#   '5',
#   'talk',
#   'wikiproject',
#   'music',
#   'archive',
#   '3',
#   'talk',
#   'wikiproject',
#   'music',
#   'archive',
#   '2',
#   '2c',
#   'music',
#   'list',
#   'sound',
#   'list',
#   'featured',
#   'music',
#   'wikipedia',
#   'classical',
#   'music',
#   'imo',
#   'impressive'],
#  ['process',
#   'rfa',
#   'listed',
#   'september',
#   '2004',
#   'differences',
#   'el',
#   'surprised',
#   'block',
#   'left',
#   'note'],
#  ['straw',
#   'argument',
#   'claimed',
#   'position',
#   'researchers',
#   'field',
#   'position',
#   'quote',
#   'agrees',
#   'notion',
#   'absurd',
#   'claim',
#   'sexual',
#   'orientation',
#   'researchers',
#   'hold',
#   'position',
#   'unfair',
#   'absurd',
#   'disorder',
#   'divided',
#   'field',
#   'argue',
#   'disorder',
#   'day',
#   'judgment',
#   'earlier',
#   'thread',
#   'scientific',
#   'judgement',
#   'choose',
#   'judgment',
#   'article',
#   'stated',
#   'pretend',
#   'scientific',
#   'basis'],
#  ['asia',
#   'includes',
#   'china',
#   'river',
#   'korea',
#   'specific',
#   'fine',
#   'citation',
#   'comprehensive',
#   'dna',
#   'study',
#   'hammer',
#   'speculation',
#   'citation',
#   'culture',
#   'brought',
#   'japan',
#   'korea',
#   'trace',
#   'roots',
#   'asia',
#   'south',
#   'china',
#   '2005',
#   'dna',
#   'study',
#   'hammer',
#   'describes',
#   'korea',
#   'based',
#   'close',
#   'entire',
#   'proposed',
#   'asian',
#   'origin',
#   'definition',
#   'asia',
#   'includes',
#   'southern',
#   'china',
#   'asia',
#   'brought',
#   'korea',
#   'eventually',
#   'japan',
#   'paragraph',
#   'propose',
#   'origins',
#   'asia',
#   'origin',
#   'region',
#   'hammer',
#   'dna',
#   'study',
#   'based',
#   'global',
#   'sample',
#   '2',
#   '500',
#   'males',
#   'asian',
#   'populations',
#   'including',
#   'populations',
#   'japanese'],
#  ['pretty',
#   'warren',
#   'county',
#   'surrounding',
#   'regions',
#   'born',
#   'falls',
#   'hospital',
#   'included',
#   'qualifies',
#   'falls',
#   'native',
#   'ray',
#   'town',
#   'lake',
#   'preceding',
#   'unsigned',
#   'comment',
#   '70',
#   '100',
#   '229',
#   '154',
#   '04',
#   '28',
#   '57',
#   'august',
#   '19',
#   '2007',
#   'utc'],
#  ['explicit', 'block', 'edit', 'warring', 'giant', 'wp', 'edits', 'terrorism'],
#  ['notability',
#   'tag',
#   'requesting',
#   'speedily',
#   'deleted',
#   'wikipedia',
#   'article',
#   'person',
#   'people',
#   'band',
#   'club',
#   'company',
#   'content',
#   'subject',
#   'notable',
#   'article',
#   'subject',
#   'included',
#   'wikipedia',
#   'criteria',
#   'speedy',
#   'deletion',
#   'articles',
#   'assert',
#   'notability',
#   'deleted',
#   'time',
#   'guidelines',
#   'accepted',
#   'notable',
#   'subject',
#   'article',
#   'notable',
#   'contest',
#   'tagging',
#   'add',
#   'existing',
#   'db',
#   'tag',
#   'leave',
#   'note',
#   'article',
#   'talk',
#   'explaining',
#   'position',
#   'remove',
#   'speedy',
#   'deletion',
#   'tag',
#   'hesitate',
#   'add',
#   'article',
#   'confirm',
#   'subject',
#   'notability',
#   'guidelines',
#   'guidelines',
#   'specific',
#   'types',
#   'articles',
#   'check',
#   'criteria',
#   'biographies',
#   'sites',
#   'bands',
#   'companies',
#   'feel',
#   'leave',
#   'note',
#   'talk',
#   'questions'],
#  ['lead',
#   'summarize',
#   'armenia',
#   'history',
#   'simply',
#   'sentence',
#   'redundant',
#   'lead',
#   'remove',
#   'edits',
#   'talk'],
#  ['responded', 'responses', 'response', 'wp', 'chicago', 'wp'],
#  ['gay',
#   'white',
#   'tiger',
#   'uh',
#   'erased',
#   'comment',
#   'holocaust',
#   'jews',
#   '1',
#   'anti',
#   'head',
#   '2',
#   'doubt',
#   'bible',
#   'homosexuality',
#   'sin',
#   'gay',
#   '3',
#   'warning',
#   'fucking',
#   'gay',
#   'nazi',
#   'write',
#   'talk',
#   'dark'],
#  ['fuck', 'mother', 'ass', 'dry'],
#  ['talk',
#   'bad',
#   'templates',
#   'talk',
#   'helps',
#   'assert',
#   'bow',
#   'administrators',
#   'play',
#   'mom',
#   '76',
#   '122',
#   '79',
#   '82'],
#  ['criticism',
#   'rule',
#   'neutral',
#   'view',
#   'offer',
#   'concerned',
#   'review',
#   'thinking',
#   'lies',
#   'perfectly',
#   'valid',
#   'telling',
#   'truth',
#   'argue',
#   'machine',
#   'story',
#   'verify',
#   'false',
#   'version',
#   'events',
#   'accused',
#   'happened',
#   'arguing',
#   'respected',
#   'phd',
#   'baseless',
#   'respected',
#   'phd',
#   'agree',
#   'edit',
#   'neutral',
#   'apologize'],
#  ['encyclopedic', 'notability', 'significance'],
#  ['lazy', 'change', 'approach', 'tag'],
#  ['claims',
#   'stalking',
#   'absolute',
#   'rubbish',
#   'serves',
#   'situation',
#   'assumed',
#   'faith',
#   'intentions',
#   'suggested',
#   'reason',
#   'motive',
#   'mass',
#   'adding',
#   'links',
#   'specific',
#   'company',
#   'matter',
#   'suggestion',
#   'administrative',
#   'matter',
#   'mentioned',
#   'role',
#   'party',
#   'disagreement',
#   'rate',
#   'conflict',
#   'extend',
#   'faith',
#   'spurious',
#   'unfounded',
#   'accusations'],
#  ['consensus',
#   'allegedly',
#   'claims',
#   'rhetoric',
#   'fascism',
#   'power',
#   'consistently',
#   'wing',
#   'force',
#   'aware',
#   'numerous',
#   'books',
#   'subject',
#   'consensus',
#   'consensus',
#   'developed',
#   'respected',
#   'scholars',
#   'fascism',
#   'write',
#   'manner',
#   'bias',
#   'roger',
#   'roger',
#   'fascism',
#   'references',
#   'aware',
#   'fascism',
#   'connections',
#   'radical',
#   'street',
#   'level',
#   'distance',
#   'movements',
#   'educated',
#   'people',
#   'position',
#   'write',
#   'books',
#   'expert',
#   'fascism',
#   'communist',
#   'party',
#   'socialist',
#   'party',
#   'italy',
#   'cover',
#   'origins',
#   'status',
#   'wrote',
#   'definitive',
#   'volume',
#   'piece'],
#  ['talk',
#   'lead',
#   'written',
#   '1994',
#   'concept',
#   'cost',
#   'space',
#   'concepts',
#   'addition',
#   'deemed',
#   'presently',
#   'materials',
#   'addition',
#   'deemed',
#   'presently',
#   'materials',
#   'statement',
#   'appears',
#   '3',
#   'quote',
#   'mass',
#   'started',
#   '200',
#   'times',
#   'mass',
#   'indication',
#   'considered',
#   'presently',
#   'materials',
#   'application',
#   'future',
#   'materials',
#   'presently',
#   'commercial',
#   'materials',
#   'suffice',
#   'primary',
#   'message',
#   'leave',
#   'reader',
#   'magic',
#   'materials',
#   'carbon',
#   'space',
#   'existing',
#   'materials',
#   'reference',
#   'mass',
#   '200',
#   'times',
#   'mass',
#   'mass',
#   'upper',
#   'limit',
#   'systems',
#   'mass',
#   '200',
#   'times',
#   'mass',
#   'built',
#   'presently',
#   'commercial',
#   'materials',
#   'conclusion',
#   'report',
#   'fundamental',
#   'conclusion',
#   'phase',
#   'study',
#   'effort',
#   'concept',
#   'technically',
#   'alternate',
#   'air',
#   'vehicle',
#   'combined',
#   'space',
#   'provide',
#   'method',
#   'moving',
#   'surface',
#   'earth',
#   'earth',
#   'architecture',
#   'concept',
#   'developed',
#   'design',
#   'solution',
#   'existing',
#   'term',
#   'expect',
#   'architecture',
#   'concepts',
#   'prove',
#   'technically',
#   'detailed',
#   'design',
#   'studies',
#   'systems',
#   'completely',
#   'potential',
#   'cost',
#   'earth',
#   'space',
#   'access',
#   'concepts',
#   '2000',
#   'report',
#   'concluded',
#   'concept',
#   'concepts',
#   'quote',
#   '1995',
#   'proposed',
#   'solution',
#   'space',
#   'speed',
#   'space',
#   'increasing'],
#  ['fucked', 'drink', 'fuck', 'fucked', 'fucked'],
#  ['threatening',
#   'neutrality',
#   'country',
#   'common',
#   'bully',
#   'discussion',
#   'push',
#   'russia'],
#  ['researching',
#   'status',
#   'texas',
#   'government',
#   'including',
#   'local',
#   'government',
#   'copyright',
#   'status',
#   'slow',
#   'florida',
#   'government',
#   'public',
#   'domain',
#   'article',
#   'texas',
#   'guess',
#   'lazy',
#   'reliable',
#   'copyright',
#   'desk',
#   'suggested',
#   'fair',
#   'rationale',
#   'valid',
#   'image',
#   'article'],
#  ['awesome', 'simply', 'disregard', 'notice'],
#  ['stupid',
#   'peace',
#   'shit',
#   'deleting',
#   'stuff',
#   'asshole',
#   'die',
#   'fall',
#   'hole'],
#  ['tony', 'loves', 'arm', 'ass'],
#  ['review',
#   'fail',
#   'article',
#   'major',
#   'brought',
#   'article',
#   'previous',
#   'assessment',
#   'issued',
#   'article',
#   'wp',
#   'lead',
#   'history',
#   'media',
#   'attention',
#   'academics',
#   'student',
#   'government',
#   'demographics',
#   'trivia',
#   'additional',
#   'additional',
#   'rest',
#   'article',
#   'wp',
#   'class',
#   'assessed',
#   'article',
#   'class',
#   'meet',
#   'class',
#   'criteria'],
#  ['band',
#   'deletion',
#   'deleting',
#   'comment',
#   'posted',
#   'talk',
#   'delete',
#   'feelings',
#   'decision',
#   'delete',
#   'sir',
#   'cock',
#   'sucking',
#   'douche',
#   'fuck',
#   'sit',
#   'life',
#   'nope',
#   'aware',
#   'life',
#   'sitting',
#   'fictional',
#   'attempts',
#   'rid',
#   'constantly',
#   'sucking',
#   'dick',
#   'failure',
#   'personal',
#   'attack',
#   'huh',
#   'bad',
#   'delete',
#   'profile',
#   'wikipedia',
#   'talk',
#   'insult',
#   'dick',
#   'innocent',
#   'college',
#   'band',
#   'happy',
#   'fucking',
#   'people',
#   'single',
#   'dead',
#   'job',
#   'spot',
#   'follow',
#   'hold',
#   'suffer',
#   'threats',
#   'lines',
#   'hurt',
#   'eat',
#   'children',
#   'sister',
#   'asshole',
#   'son',
#   'bitch',
#   'mother',
#   'fucking',
#   'cock',
#   'eat',
#   'food',
#   'headed',
#   'fuck',
#   'nice',
#   'couple',
#   'local',
#   'store',
#   'jack',
#   'minutes',
#   'tonight',
#   'sincerely',
#   'asshole'],
#  ['fat',
#   'tonight',
#   'jay',
#   'absolutely',
#   'awful',
#   'money',
#   'candidate',
#   '2007',
#   'dead',
#   'pool',
#   'kindly',
#   'malicious',
#   'comment',
#   'remove',
#   'repost'],
#  ['violate', 'wp', 'conservatives', 'wikipedians'],
#  ['homosexual',
#   'defined',
#   'sexual',
#   'activity',
#   '15',
#   'boy',
#   'girl',
#   'sex',
#   'straight',
#   'person',
#   'sex',
#   'sex'],
#  ['redirect', 'talk', 'frank'],
#  ['christian',
#   'arabs',
#   'category',
#   'christian',
#   'arabs',
#   'arabic',
#   'christians',
#   'living',
#   'middle',
#   'east',
#   'wrong',
#   'middle',
#   'eastern',
#   'christians',
#   'arabs',
#   'arabs',
#   'ethnicity',
#   'forced',
#   'called',
#   'christian',
#   'arabs',
#   'christian',
#   'european',
#   'born',
#   'middle',
#   'east',
#   'called',
#   'christian',
#   'arab',
#   'reason',
#   'understand',
#   'christians',
#   'assyrian',
#   'ancestry',
#   'speak',
#   'lot',
#   'speaks',
#   'respect',
#   'muslims',
#   'arabs',
#   'middle',
#   'east',
#   'closely',
#   'arabs',
#   'ethnicity',
#   'forcing',
#   'alien',
#   'arab',
#   'ethnicity',
#   'talk',
#   '12',
#   '17',
#   '26',
#   'jun',
#   '2007',
#   'utc'],
#  ['dude', 'abc', 'officially', 'episode', 'episode', 'abc'],
#  ['edits',
#   'cunts',
#   'revert',
#   'edits',
#   'stupid',
#   'understand',
#   'write',
#   'revert',
#   'edits',
#   'decided',
#   'bear',
#   'day',
#   'realise',
#   'damage',
#   'noble',
#   'project',
#   '201',
#   '215',
#   '187',
#   '159'],
#  ['neiln', 'bang', 'harassed', 'edit', 'reverted', 'talk'],
#  ['time', 'time', 'stopped', 'children', 'age'],
#  ['chemical',
#   'guys',
#   'writing',
#   'feel',
#   'law',
#   'school',
#   'legal',
#   'profession',
#   'bad'],
#  ['scare', 'comments', 'insulting', 'original', 'wikipedia'],
#  ['oppose',
#   'article',
#   'stands',
#   'properly',
#   'reference',
#   'wp',
#   'reference',
#   'guidelines',
#   'issue',
#   'resolved',
#   'issues',
#   'moved',
#   'mainspace'],
#  ['apology',
#   'waste',
#   'time',
#   'attempts',
#   'justify',
#   'physics',
#   'bother',
#   'issue',
#   'leave',
#   'seek',
#   'deserve',
#   'attention'],
#  ['original', 'episodes'],
#  ['ambiguous',
#   'irish',
#   'preceding',
#   'unsigned',
#   'comment',
#   '109',
#   '77',
#   '58',
#   '139',
#   'word',
#   'irish',
#   'invented',
#   'establishment',
#   'irish',
#   'talk',
#   'quote',
#   'depends',
#   'context',
#   'term',
#   'applicable',
#   'note',
#   'citizenship',
#   'ethnicity',
#   'mentioned',
#   'nationality',
#   'real',
#   'key',
#   'meaning',
#   'nationality',
#   'meaning',
#   'term',
#   'form',
#   'wikipedia',
#   'nationality',
#   'terms',
#   'refers',
#   'republic',
#   'ireland',
#   'talk',
#   'nationality',
#   'terms',
#   'refers',
#   'republic',
#   'ireland',
#   'country',
#   'nationality',
#   'terms',
#   'refers',
#   'ireland',
#   'preceding',
#   'unsigned',
#   'comment',
#   '109',
#   '76',
#   '191',
#   '188',
#   'wow',
#   'ireland',
#   'ireland',
#   'official',
#   'description',
#   'republic',
#   'ireland',
#   'conversation',
#   'talk',
#   'ireland',
#   'official',
#   'ireland',
#   'preceding',
#   'unsigned',
#   'comment',
#   '109',
#   '76',
#   '191',
#   '188',
#   'constitution',
#   'reports',
#   'pdf',
#   'reading',
#   'constitution',
#   'reports',
#   'pdf',
#   'speak',
#   'preceding',
#   'unsigned',
#   'comment',
#   '109',
#   '78',
#   '224',
#   '50'],
#  ['magazine', 'time', 'corporate', 'time', 'easily', 'hand', 'corporate'],
#  ['late'],
#  ['dick', 'talk', 'bad', 'express', 'properly', 'concern', 'cheers'],
#  ['direction',
#   'recognize',
#   'american',
#   'encyclopedia',
#   'universal',
#   'single',
#   'recognize',
#   'named'],
#  ['20',
#   'december',
#   '2006',
#   'utc',
#   'play',
#   'metal',
#   'solid',
#   '2',
#   'solid',
#   'uploaded',
#   'virus',
#   '19',
#   '32'],
#  ['warning', 'edits', 'die'],
#  ['proposed',
#   'deletion',
#   'template',
#   'article',
#   'suggesting',
#   'deleted',
#   'proposed',
#   'deletion',
#   'process',
#   'contributions',
#   'appreciated',
#   'article',
#   'satisfy',
#   'wikipedia',
#   'criteria',
#   'inclusion',
#   'deletion',
#   'notice',
#   'explain',
#   'wikipedia',
#   'wikipedia',
#   'deletion',
#   'policy',
#   'prevent',
#   'proposed',
#   'deletion',
#   'removing',
#   'notice',
#   'explain',
#   'disagree',
#   'proposed',
#   'deletion',
#   'edit',
#   'summary',
#   'talk',
#   'improving',
#   'article',
#   'address',
#   'issues',
#   'raised',
#   'removing',
#   'deletion',
#   'notice',
#   'prevent',
#   'deletion',
#   'proposed',
#   'deletion',
#   'process',
#   'article',
#   'deleted',
#   'matches',
#   'speedy',
#   'deletion',
#   'criteria',
#   'articles',
#   'deletion',
#   'deleted',
#   'consensus',
#   'delete',
#   'reached',
#   'agree',
#   'deletion',
#   'article',
#   'person',
#   'substantial',
#   'edits',
#   'add'],
#  ['scientific',
#   'attribute',
#   'event',
#   'deliberate',
#   'designed',
#   'sort',
#   'intelligent',
#   'intent',
#   'answer',
#   'questions',
#   'answering',
#   'completely',
#   'major',
#   'fundamental',
#   'completely',
#   'fail',
#   'mention',
#   'intelligence',
#   'literally',
#   'earth',
#   'natural',
#   'science',
#   'built',
#   'odd',
#   'odd',
#   'fundamentally',
#   'earth',
#   'core',
#   'notion',
#   'science',
#   'sense',
#   'word',
#   'mythology',
#   'paul',
#   'wrestling',
#   'match',
#   'blue',
#   'kicked',
#   'created',
#   'evidence',
#   'paul',
#   'remain',
#   'natural',
#   'science',
#   'takes',
#   'approach',
#   'knowledge',
#   'scientific',
#   'law',
#   'theories',
#   'heavy',
#   'supporting',
#   'data',
#   'head',
#   'knowledge',
#   'plays',
#   'games',
#   'formed',
#   'naturally',
#   'sort',
#   'accurate',
#   'probability',
#   'naturally',
#   'understand',
#   'statistics',
#   'takes',
#   'complete',
#   'detailed',
#   'natural',
#   'explanation',
#   'statistics',
#   'happen',
#   'designed',
#   'science',
#   'understand',
#   'finally',
#   'deliberate',
#   'design',
#   'respect',
#   'life',
#   'earth',
#   'unknown',
#   'qualify',
#   'science',
#   'dead',
#   'body',
#   'bullet',
#   'heart',
#   'bunch',
#   'dead',
#   'bodies',
#   'heart',
#   'time',
#   'body',
#   'bullet',
#   'heart',
#   'figure',
#   'killed',
#   'life',
#   'earth',
#   'sense',
#   'scientific',
#   'observed',
#   'btw',
#   'teh',
#   'intelligent',
#   'observed',
#   'sense',
#   'science'],
#  ['hey',
#   'noticed',
#   'comments',
#   'discussion',
#   'decided',
#   'account',
#   'objected',
#   'change',
#   'fair',
#   'changed',
#   'paragraph',
#   'bothered',
#   'fine',
#   'fighting'],
#  ['april',
#   '2006',
#   'experimenting',
#   'andy',
#   'wikipedia',
#   'reverted',
#   'removed',
#   'sandbox',
#   'tests',
#   'learn',
#   'contributing',
#   'encyclopedia'],
#  ['christ', 'selected', 'population'],
#  ['prove', 'knowledge', 'english', 'language', 'obvious'],
#  ['shut', 'wikipedia', 'stupid', 'kid'],
#  ['vandalising'],
#  ['hey',
#   'thinking',
#   'display',
#   'pictures',
#   'guys',
#   'websites',
#   'legit',
#   'provide',
#   'alternatives',
#   'appreciated',
#   'talk'],
#  ['reading'],
#  ['personal',
#   'attacks',
#   'fruit',
#   'vfd',
#   'apologies',
#   'critical',
#   'feel',
#   'comments',
#   'fruit',
#   'vfd',
#   'debate',
#   'reasonable',
#   'disagree',
#   'assertion',
#   'initial',
#   'sentence',
#   'lie',
#   'learn',
#   'life',
#   'attacks',
#   'age',
#   'border',
#   'personal',
#   'attack',
#   'included',
#   'comment',
#   'expect',
#   'apologise',
#   'comments',
#   'vfd',
#   'debate',
#   'inappropriate',
#   'community',
#   'agree',
#   'talk',
#   '06',
#   '46',
#   '2005',
#   'feb',
#   '7',
#   'utc'],
#  ['russian',
#   'names',
#   'writing',
#   'metro',
#   'wikipedia',
#   'finding',
#   'difficult',
#   'correctly',
#   'russian',
#   'names',
#   'park',
#   'completely',
#   'list',
#   'https',
#   'wikipedia',
#   'wiki',
#   'putting',
#   'list'],
#  ['real', 'talk'],
#  ['fort', 'shooting', 'justified', 'god', 'law'],
#  ['lack',
#   'balance',
#   'article',
#   'balance',
#   'benefit',
#   'greatly',
#   'introduction',
#   'additional',
#   'negative',
#   'aspects',
#   '34',
#   'record',
#   'sort',
#   'balance',
#   'author',
#   'testing',
#   '34',
#   'army',
#   'exposed',
#   'tank',
#   'type',
#   'included',
#   'article',
#   'bring',
#   'balance'],
#  ['violating',
#   'stated',
#   'wikipedia',
#   'policy',
#   'people',
#   'reviewed',
#   'wiki',
#   'project',
#   'spending',
#   'rest',
#   'day',
#   'personal',
#   'blog',
#   'entry',
#   'discussions',
#   'james',
#   'fascinating',
#   'discussion',
#   'term',
#   'jewish',
#   'deleted',
#   'voice',
#   'article',
#   'talk',
#   'jewish',
#   'wp',
#   'comparing',
#   'jewish',
#   'virtual',
#   'library',
#   'voice',
#   'moore',
#   'talk'],
#  ['talk'],
#  ['regarded', 'form', 'mention', 'warranted'],
#  ['resolved',
#   'write',
#   'edit',
#   'summary',
#   'camera',
#   'edit',
#   'summary',
#   'box',
#   'talk'],
#  ['username', 'impact', 'familiar', 'username', 'takes', 'talk', 'contribs'],
#  ['edit', 'golden', 'wake', 'funny'],
#  ['check', 'websites', 'php', 'islam'],
#  ['games'],
#  ['provide',
#   'diffs',
#   'hour',
#   'edit',
#   'edit',
#   'talk',
#   'provide',
#   'diffs',
#   'requested',
#   'hour',
#   'edit',
#   'sanctioned',
#   'failing',
#   'provide',
#   'requested',
#   'diffs',
#   'manner',
#   'week',
#   'request',
#   'lift',
#   'sanction',
#   'denied'],
#  ['characters', 'black', 'doom'],
#  ['pair', 'jew', 'nazi'],
#  ['tend',
#   'list',
#   'rest',
#   'article',
#   'history',
#   'characteristics',
#   'expanded',
#   'list',
#   'personally',
#   'consensus',
#   'reached',
#   'article',
#   'included',
#   'decided',
#   'country',
#   'origin',
#   'examples',
#   'foreign',
#   'foreign',
#   'includes',
#   'examples',
#   'article',
#   'article',
#   'encyclopedia',
#   'list',
#   'people',
#   'lists',
#   'article',
#   'reference',
#   'style',
#   'statistics',
#   'bad',
#   'style',
#   'statistics',
#   'sounds',
#   'description',
#   'encyclopedia',
#   'follow',
#   'citation',
#   'follow',
#   'valid',
#   'style',
#   'country',
#   'origin'],
#  ['politically',
#   'motivated',
#   'push',
#   'issue',
#   'refrain',
#   'talking',
#   'feel',
#   'talk',
#   'relevant',
#   'edits',
#   'science',
#   'talk',
#   'prefer',
#   'users',
#   'post',
#   'guy',
#   'published',
#   'psychology',
#   'researcher',
#   'access',
#   'sources',
#   'mind',
#   'suspect',
#   'editor',
#   'racist',
#   'wiki',
#   '121',
#   '134',
#   '219',
#   '36'],
#  ['vandalizing', 'fun', 'sense', 'humor', 'vandalizing', 'stuff'],
#  ['wikipedia',
#   'discover',
#   'practical',
#   'encyclopedia',
#   'alternative',
#   'life',
#   'techniques',
#   'discover',
#   'practical',
#   'encyclopedia',
#   'alternative',
#   'life',
#   'techniques'],
#  ['including', 'mention', 'article', 'level', 'support'],
#  ['comment', 'verify', 'claim', 'talk'],
#  ['czech',
#   'republic',
#   'central',
#   'europe',
#   'article',
#   'reason',
#   'people',
#   'ridiculous',
#   'replace',
#   'mention',
#   'north',
#   'favor',
#   'north',
#   'mountains',
#   'geographical',
#   'mountains',
#   'region',
#   'countries',
#   'located',
#   'reason',
#   'refuse',
#   'article',
#   'single',
#   'factor',
#   'massive',
#   'difference',
#   'readers',
#   'tired',
#   'arguing',
#   'people',
#   'essentially',
#   'wiki',
#   'refusing',
#   'article',
#   '24',
#   '90',
#   '230',
#   '216'],
#  ['enjoyed',
#   'meeting',
#   'shocked',
#   'decision',
#   'reflect',
#   'consensus',
#   'grand',
#   'serves',
#   'time',
#   'real',
#   'fun',
#   'hobby',
#   'learned',
#   'lesson',
#   'waste',
#   'time',
#   'stick',
#   'fixing',
#   'read',
#   'articles'],
#  ['agree',
#   'remains',
#   'buried',
#   'preserved',
#   'term',
#   'precise',
#   'term',
#   'factors',
#   'processes',
#   'occur',
#   'remains',
#   'result',
#   'typically',
#   'called',
#   'major',
#   'factor',
#   'concerns',
#   'plants',
#   'foot',
#   'multiple',
#   'processes',
#   'include',
#   'replacement',
#   'talking',
#   'complex',
#   'issue',
#   'quick',
#   'questioned',
#   'major',
#   'question',
#   'processes',
#   'environment',
#   'experimental',
#   'remains',
#   'processes',
#   'lab',
#   'implies',
#   'conditions',
#   'vast',
#   'ages',
#   'issue',
#   'processes',
#   'ongoing',
#   'met',
#   'chemical',
#   'remains',
#   'expect',
#   'remains',
#   'buried',
#   'completely',
#   'period',
#   'processes',
#   'remains',
#   'view',
#   'choose'],
#  ['wikipedia'],
#  ['reference',
#   'magazine',
#   'engineering',
#   'journal',
#   'difficult',
#   'time',
#   'finding',
#   'depending',
#   'live',
#   'article',
#   'researching',
#   'derived',
#   'press',
#   'accounts',
#   'incident',
#   'joke',
#   'citing',
#   'incident',
#   'created',
#   '40',
#   'leave',
#   'email',
#   'scan',
#   'email',
#   'pdf'],
#  ['trust', 'books', 'google', 'books', 'dq', 'hl', 'en', 'false'],
#  ['chart',
#   'performance',
#   'single',
#   'advice',
#   'split',
#   'paragraphs',
#   'short',
#   'paragraphs',
#   'hard',
#   'boring',
#   'splitting',
#   'paragraphs',
#   'improve',
#   'flow',
#   'talk'],
#  ['removed'],
#  ['temporarily',
#   'removed',
#   'requests',
#   'based',
#   'advice',
#   'pending',
#   'request',
#   'consensus',
#   'talk',
#   'urge',
#   'reading',
#   'vote',
#   'community'],
#  ['healthy',
#   'missed',
#   'article',
#   'address',
#   'healthy',
#   'behaviour',
#   'conform',
#   'grammar',
#   'understood',
#   'conform',
#   'laws',
#   'recognise',
#   'society',
#   '194',
#   '126',
#   '85',
#   '214'],
#  ['wikipedia',
#   'read',
#   'impressed',
#   'quality',
#   'knowledge',
#   'easily',
#   'easily',
#   'accessible',
#   'format',
#   'creating',
#   'content',
#   'accessible'],
#  ['views',
#   'socialist',
#   'political',
#   'link',
#   'mentions',
#   'bit',
#   'stood',
#   'election',
#   'candidate',
#   'respect'],
#  ['sandbox',
#   'template',
#   'sandbox',
#   'remove',
#   'reason',
#   '11',
#   '36',
#   'jan',
#   '2005',
#   'utc'],
#  ['heh',
#   'bit',
#   'wikipedia',
#   'wikiproject',
#   'professional',
#   'wrestling',
#   'bit'],
#  ['203',
#   '92',
#   '84',
#   '161',
#   'symbols',
#   '♦',
#   'characters',
#   'greek',
#   'ipa',
#   'famous',
#   'article',
#   'wikipedia',
#   'passed',
#   'generations',
#   'families',
#   'race',
#   'age',
#   'character',
#   'knowledge',
#   'characters',
#   'job',
#   'person',
#   'called',
#   'cool',
#   'lesser',
#   '11',
#   'boy',
#   'awesome',
#   'told',
#   'people',
#   'testimony',
#   'history',
#   'knowledge',
#   'public',
#   'abide',
#   'time',
#   'term',
#   'word',
#   'adjective',
#   'century',
#   'term',
#   'person',
#   'extreme',
#   'humour',
#   'intelligence',
#   'bad',
#   'wind',
#   'reasons',
#   'proper',
#   'history',
#   'century',
#   'considered',
#   'children',
#   'encouraged',
#   'led',
#   '1st',
#   'current',
#   'followers',
#   'attempted',
#   'coup',
#   'local',
#   'council',
#   'chess',
#   'team',
#   'followers',
#   'pronounced',
#   'government',
#   'meeting',
#   'period',
#   'dark',
#   'time',
#   'history',
#   'times',
#   'normal',
#   'people',
#   'mass',
#   'protests',
#   '1980s',
#   'building',
#   'moment',
#   'history',
#   '1988',
#   'visitors',
#   'gallery',
#   'house',
#   'commons',
#   'wearing',
#   'clown',
#   'completely',
#   'naked',
#   'people',
#   'behaviour',
#   'mentally',
#   'life',
#   'people',
#   'included',
#   'children',
#   'forced',
#   'mental',
#   'suffering',
#   'time',
#   'government',
#   'finally',
#   'positive',
#   'action',
#   '1990',
#   'rights',
#   'signed',
#   'stating',
#   'allowed',
#   'pleased',
#   'formal',
#   'agreement',
#   'journalists',
#   'viewed',
#   'letter',
#   'submission',
#   'government',
#   'behaviour',
#   'followers'],
#  ['finished',
#   'planned',
#   'cleanup',
#   'entries',
#   'removed',
#   'copied',
#   'entries',
#   'record',
#   'looked',
#   'talk'],
#  ['dec',
#   '14',
#   '2006',
#   'scientist',
#   'collapse',
#   'dr',
#   'wood',
#   'scientific',
#   'method',
#   'applied',
#   'hypothesis',
#   'paper',
#   'links'],
#  ['statement',
#   'drawn',
#   'literature',
#   'honestly',
#   'hypocrisy',
#   'drawn',
#   'literature',
#   'ray',
#   'arguments',
#   'literature',
#   'imposed',
#   'wikipedia',
#   'article',
#   'coincidence',
#   'ray',
#   'reference',
#   'literature',
#   'connection',
#   'ray',
#   'connection',
#   'ray',
#   'literature',
#   'natural',
#   'nature'],
#  ['checked',
#   'bay',
#   'missed',
#   'disambiguation',
#   'completely',
#   'apologies',
#   'late',
#   'night'],
#  ['evidence', 'derived', 'objects', 'citation', 'note', 'article'],
#  ['expansion',
#   'citations',
#   'images',
#   'pic',
#   'cup',
#   'banner',
#   'tonight',
#   'game',
#   'forgot',
#   'camera',
#   'review',
#   'edit'],
#  ['redirect',
#   'hurt',
#   'candidates',
#   'ideal',
#   'passes',
#   'notability',
#   'day',
#   'basic',
#   'material'],
#  ['article',
#   'style',
#   'standard',
#   'wikipedia',
#   'articles',
#   'deleted',
#   'pretty',
#   'stayed',
#   'form',
#   'posted',
#   'grateful',
#   'talk',
#   'accuracy',
#   'remove',
#   'links',
#   'conflict',
#   'guidelines',
#   'advise',
#   'editors',
#   'linking',
#   'sites',
#   'wikipedia',
#   'attribution',
#   'policy',
#   'wp',
#   'requires',
#   'party',
#   'published',
#   'sources',
#   'personal',
#   'websites',
#   'newspaper',
#   'book',
#   'accounts',
#   'ps',
#   'personal'],
#  ['article',
#   'warrant',
#   'flame',
#   'trees',
#   'article',
#   'discography',
#   'article',
#   'stand',
#   '22',
#   '2005'],
#  ['yeah', 'merge', 'content', 'devil', 'type'],
#  ['image', 'jpg', 'photo', 'replace', 'current', 'check'],
#  ['cookie', 'cookie'],
#  ['lmao', 'listen'],
#  ['06',
#   '29',
#   'december',
#   '2007',
#   'utc',
#   'yep',
#   'lol',
#   'party',
#   'serbia',
#   'party',
#   '20th',
#   'election',
#   'winning',
#   'votes',
#   'notable',
#   'mentioned',
#   'people',
#   'figured',
#   'constitution',
#   'serbia',
#   'brought',
#   'kosovo',
#   '1990',
#   'constitution',
#   'possibility',
#   'military',
#   'technical',
#   'agreement',
#   'signed',
#   'broke',
#   'government',
#   'causing',
#   'elections',
#   'maximum',
#   'sentence',
#   'death',
#   'trial',
#   'serbia',
#   'reasons',
#   'constitution',
#   'releases',
#   'authorities',
#   'weight',
#   'prison',
#   'recognize',
#   'form',
#   'loss',
#   'kosovo',
#   '15'],
#  ['wikiproject',
#   'novels',
#   'begun',
#   'wikiproject',
#   'novels',
#   'improvement',
#   'drive',
#   'listed',
#   'notified',
#   'wikipedia',
#   'talk',
#   'wikiproject',
#   'novels',
#   '5',
#   '5',
#   '5',
#   'improvement',
#   'drive',
#   'wikipedia',
#   'wikiproject',
#   'novels',
#   'collaboration',
#   'details',
#   'remind',
#   'eye',
#   'project',
#   'talk',
#   'wikipedia',
#   'talk',
#   'wikiproject',
#   'novels'],
#  ['reply',
#   'message',
#   'evidence',
#   'claims',
#   'talk',
#   'glad',
#   'provide',
#   'failed',
#   'provide',
#   'diffs',
#   'message',
#   'claiming',
#   'wp',
#   'assume',
#   'faith',
#   'users',
#   'constantly',
#   'harass',
#   'follow',
#   'articles',
#   'disruptive',
#   'edits',
#   'violation',
#   'numerous',
#   'wikipedia',
#   'guidelines',
#   'wp',
#   'harass',
#   'removal',
#   'party',
#   'references',
#   'articles',
#   'suit',
#   'pov',
#   'entering',
#   'edit',
#   'summary',
#   'considered',
#   'wikipedia',
#   'guidelines',
#   'bad',
#   'faith',
#   'violation',
#   'wp',
#   'blank',
#   'violation',
#   'wp',
#   'neo',
#   'adding',
#   'derogatory',
#   'articles',
#   'organisations',
#   'personally',
#   'agree',
#   'aware',
#   'policy',
#   'reference',
#   'organisation',
#   'community',
#   'majority',
#   'constantly',
#   'removing',
#   'derogatory',
#   'term',
#   'tag',
#   'team',
#   'numerous',
#   'editors',
#   'edit',
#   'articles',
#   'british',
#   'culture',
#   'counties',
#   'evidence',
#   'messages',
#   'talkpage',
#   'lovely',
#   'mediation',
#   'familiar',
#   'violation',
#   'wp',
#   'wikipedia',
#   'admin',
#   'familiar',
#   'policies',
#   'guidelines',
#   'referenced',
#   'message',
#   'accusing',
#   'user',
#   'personal',
#   'attacks',
#   'bias',
#   'acceptable',
#   'policies',
#   'sake',
#   'friend'],
#  ['polite',
#   'talk',
#   'people',
#   'remove',
#   'comments',
#   'talk',
#   'check',
#   'previous',
#   'edit',
#   'spelled',
#   'finding',
#   'spell',
#   'correctly',
#   'edits'],
#  ['block', 'wondering', 'confirmed', 'block'],
#  ['opinion',
#   'continues',
#   'personal',
#   'remarks',
#   'assume',
#   'wp',
#   'rfc',
#   'violated',
#   '3rr',
#   'rule',
#   'edit',
#   'warring',
#   'accurate',
#   'word',
#   'ridiculous',
#   'edit',
#   'warring',
#   'wrong',
#   'honest',
#   'statement',
#   'talk',
#   'assistance',
#   'questions',
#   'btw',
#   'accurate',
#   'referenced',
#   'entries',
#   'understanding',
#   'refers',
#   'precise',
#   'vital',
#   'info',
#   'sequence',
#   'events'],
#  ['iranian', 'turkic', 'nation'],
#  ['userbox',
#   'userbox',
#   'template',
#   'user',
#   'moved',
#   'user',
#   'space',
#   'wp',
#   'link',
#   'leave',
#   'questions',
#   'talk'],
#  ['time',
#   'bit',
#   'jumping',
#   'avenue',
#   'pursue',
#   'realised',
#   'probability',
#   'water',
#   'horse',
#   'terms',
#   'entity',
#   'challenged',
#   'produce',
#   'decent',
#   'guarantee',
#   'unable'],
#  ['editors',
#   'eric',
#   'issue',
#   'bear',
#   'aggressive',
#   'touch',
#   'uncivil',
#   'appears',
#   'choice',
#   'rid'],
#  ['features',
#   'smith',
#   'concept',
#   'hand',
#   'smith',
#   'social',
#   'policy',
#   'people',
#   'describing',
#   'observed',
#   'economic',
#   'reality',
#   'people',
#   'smith',
#   'claiming',
#   'beneficial',
#   'effects',
#   'community',
#   'argue',
#   'argued',
#   'view',
#   'bad',
#   'worth',
#   'noting',
#   'death',
#   'smith',
#   'left',
#   'personal',
#   'wealth',
#   'idea',
#   'adam',
#   'smith',
#   'socialist',
#   'wikipedia'],
#  ['dick',
#   'listed',
#   'batman',
#   'master',
#   'martial',
#   'artist',
#   'trained',
#   'mentioned',
#   'combat',
#   'mention',
#   'skills',
#   'abilities',
#   'battles',
#   'lost',
#   'supposed',
#   'proven',
#   'match',
#   'meta',
#   'earliest'],
#  ['alpha', 'version', 'version'],
#  ['pd',
#   'article',
#   'coat',
#   'arms',
#   'arab',
#   'democratic',
#   'republic',
#   'article',
#   'named',
#   'coat',
#   'arms',
#   'western',
#   'users',
#   'politically',
#   'driven',
#   'intentions',
#   'bad',
#   'faith',
#   'claim',
#   'neutral',
#   'neutral',
#   'coat',
#   'arms',
#   'western',
#   'article',
#   'merge',
#   'articles',
#   'messing'],
#  ['treating', 'forum', 'question', 'appropriately', 'answered', 'story'],
#  ['military',
#   'history',
#   'wikiproject',
#   'newsletter',
#   'issue',
#   'april',
#   '2006',
#   'issue',
#   'project',
#   'newsletter',
#   'read',
#   'issue',
#   'change',
#   'format',
#   'future',
#   'issues',
#   'delivered',
#   'link'],
#  ['unblock',
#   'submission',
#   'response',
#   '3',
#   'minutes',
#   'proves',
#   'administrator',
#   'pay',
#   'attention'],
#  ['request',
#   'unblocked',
#   'granted',
#   'reason',
#   'allowing',
#   'username',
#   'change',
#   'request',
#   'wikipedia',
#   'changing',
#   'username',
#   'avoid',
#   'blocking',
#   'request',
#   'handled',
#   'unblocking',
#   'administrator',
#   'check',
#   'active',
#   'user',
#   'accepting',
#   'unblock',
#   'request'],
#  ['responded',
#   'reasoning',
#   'edit',
#   'reasoning',
#   'edit',
#   'absolutely',
#   'relevant',
#   'discussion',
#   'income',
#   'progressive',
#   'tax',
#   'article'],
#  ['unblock', 'lawyers', 'blocking', 'constitutional', 'speech'],
#  ['invitation',
#   'input',
#   'culture',
#   'welcomed',
#   'defining',
#   'ideological',
#   'systems',
#   'raise',
#   'propose',
#   'liberal',
#   'variant',
#   'definition',
#   'connected',
#   'word',
#   'follow',
#   'remains',
#   'initial',
#   'ideas',
#   'branch',
#   'period',
#   'national',
#   'period',
#   'artists',
#   'writers',
#   'cultural',
#   'workers',
#   'period',
#   'definition',
#   'false',
#   'concrete',
#   'specifics',
#   'distinguish',
#   'leading',
#   'ideas',
#   'cultural',
#   'defined',
#   'cultural',
#   'context',
#   'expression',
#   'cultural',
#   'heritage',
#   'expression',
#   'simply',
#   'typically',
#   'authors',
#   'context',
#   'representative',
#   'culture',
#   'european',
#   'wide',
#   'context',
#   'parallel',
#   'literature',
#   'india',
#   'nobel',
#   'price',
#   'winner',
#   'representative',
#   'culture',
#   'india',
#   'india',
#   'understandable',
#   'closer',
#   'western',
#   'people',
#   'concerned',
#   'main',
#   'input',
#   'western',
#   'culture',
#   'country',
#   'changing',
#   'traditional',
#   'cultural',
#   'forms',
#   'cultural',
#   'leaders',
#   'cultural',
#   'forms',
#   'changing',
#   'context',
#   'wider',
#   'context',
#   'western',
#   'people',
#   'culture',
#   'direct',
#   'input',
#   'western',
#   'culture',
#   'generation',
#   '4th',
#   'decade',
#   '20th',
#   'century',
#   'concerned',
#   'western',
#   'movement',
#   'main',
#   'purpose',
#   'introduce',
#   'western',
#   'european',
#   'ideas',
#   'cultural',
#   'life',
#   'table',
#   'movements',
#   'movements',
#   'political',
#   'ideas',
#   'researchers',
#   'pay',
#   'attention',
#   'difference',
#   'soviet',
#   'period',
#   'national',
#   'ideas',
#   'officially',
#   'forbidden',
#   'description',
#   'movements',
#   'allowed',
#   'philosopher',
#   'depends',
#   'generation',
#   'liberal',
#   'understood',
#   'sense',
#   'generation',
#   'idea',
#   'period',
#   'generation',
#   'artists',
#   'writers',
#   'context',
#   'european',
#   'context',
#   'national',
#   'period',
#   'generation',
#   'philosopher',
#   'philosopher',
#   'culture',
#   'representatives',
#   'culture',
#   'unknown',
#   'period',
#   'wwii',
#   'post',
#   'war',
#   'writer',
#   'artists',
#   'philosopher',
#   'introducing',
#   'western',
#   'ideas',
#   'cultural',
#   'life',
#   'central',
#   'european',
#   'note',
#   'lists',
#   'complete',
#   'precisely',
#   '07',
#   '51',
#   '2004',
#   'jul',
#   '16',
#   'utc'],
#  ['direct',
#   'quotes',
#   'quotation',
#   'marks',
#   'attributed',
#   'plagiarism',
#   'copyright',
#   'infringement',
#   'material',
#   'issue',
#   'material',
#   'jewish',
#   'action'],
#  ['weigh',
#   'talk',
#   'inclusion',
#   'image',
#   'template',
#   'user',
#   'reverting',
#   'newsletter',
#   'issue',
#   '1',
#   'style',
#   'border',
#   'margin',
#   '100',
#   'class',
#   'mainpagebg',
#   'style',
#   '55',
#   'border',
#   '1px',
#   'solid',
#   'background',
#   'color',
#   'f5fffa',
#   'vertical',
#   'align',
#   'color',
#   '000',
#   'reach',
#   'program',
#   'aimed',
#   'allowing',
#   'users',
#   'bring',
#   'issues',
#   'wikipedia',
#   'listening',
#   'audience',
#   'feel',
#   'expect',
#   'understanding',
#   'dispute',
#   'life',
#   'issues',
#   'person',
#   'fair',
#   'wikipedia',
#   'fall',
#   'heading',
#   'bring',
#   'project',
#   'attention',
#   'stress',
#   'stress',
#   'program',
#   'identifying',
#   'users',
#   'community',
#   'stress',
#   'identify',
#   'stress',
#   'note',
#   'format',
#   'newsletter',
#   'council',
#   'meeting',
#   'hope',
#   'major',
#   'month',
#   'council',
#   'meeting',
#   'include',
#   'featured',
#   'programs',
#   'sum',
#   'meeting',
#   'signed',
#   'council',
#   'march',
#   'class',
#   'mainpagebg',
#   'style',
#   '45',
#   'border',
#   '1px',
#   'solid',
#   'background',
#   'color',
#   'vertical',
#   'align',
#   '100',
#   'cellpadding',
#   '2',
#   'cellspacing',
#   '5',
#   'style',
#   'vertical',
#   'align',
#   'background',
#   'color',
#   'ac',
#   'meeting',
#   'log',
#   'style',
#   'color',
#   '000',
#   'future',
#   'held',
#   'bans',
#   'access',
#   'level',
#   'irc',
#   'channel',
#   'reported',
#   'log',
#   'irc',
#   'channel',
#   'bot',
#   'time',
#   'requires',
#   '150',
#   'edits',
#   '2',
#   'weeks',
#   'editing',
#   'clarified',
#   'code',
#   'conduct',
#   'proposed',
#   'community',
#   'npa',
#   'reform',
#   'idea',
#   'dropped',
#   'officially',
#   'discussed',
#   'future',
#   'voted',
#   'council',
#   'proposed',
#   'expanded',
#   'council',
#   'propose',
#   'listen'],
#  ['claim', 'sockpuppet', 'claim'],
#  ['quick',
#   'limit',
#   'discussion',
#   'changing',
#   'title',
#   'previous',
#   'discussions',
#   'months',
#   'valid',
#   'reason'],
#  ['123',
#   '18',
#   '38',
#   'july',
#   '18',
#   '2005',
#   'utc',
#   'feel',
#   'leave',
#   'message',
#   'talk',
#   'simply'],
#  ['social',
#   'focused',
#   'social',
#   'aspects',
#   'climate',
#   'change',
#   'qualified',
#   'comment',
#   'consensus',
#   'historian',
#   'study',
#   'published',
#   'peer',
#   'reviewed',
#   'journal',
#   'appeared',
#   'reliable',
#   'sources',
#   'treated',
#   'scientist',
#   'conclusions',
#   'reporter',
#   'literally',
#   'thousands',
#   'wiki',
#   'articles',
#   'references',
#   'direct',
#   'quotes',
#   'scientists',
#   'source',
#   'medium',
#   'reputable',
#   'reporter'],
#  ['day',
#   'apologies',
#   'change',
#   'change',
#   'day',
#   'day',
#   'straight',
#   'biggest',
#   'star',
#   'sky',
#   'head',
#   'clock',
#   'strikes',
#   '12',
#   'day',
#   'beautiful',
#   'prove',
#   'day',
#   'black',
#   'white',
#   'prove',
#   'apologies',
#   'trouble',
#   'south',
#   'east',
#   'asia',
#   'asia',
#   'traditional',
#   'chinese',
#   'family',
#   'day'],
#  ['fired', 'lazy', 'sick', 'people', 'exist'],
#  ['violating',
#   'wp',
#   'npa',
#   'pretty',
#   'minor',
#   'content',
#   'conflict',
#   'mediation',
#   'cabal',
#   'easier',
#   'sign',
#   'typing',
#   'irc',
#   'channel',
#   'advice',
#   'talk'],
#  ['head', 'dedicated', 'wikipedians', 'love', 'barnstar', 'offer', 'head'],
#  ['note', 'sandbox'],
#  ['opinion',
#   'simple',
#   'guess',
#   'german',
#   'correct',
#   'russians',
#   'personnel',
#   'improved',
#   'combination',
#   'forced',
#   'germans',
#   'losses',
#   'battle',
#   'tanks',
#   'favor',
#   'germans',
#   'weeks',
#   'german',
#   'tank'],
#  [],
#  ['piece',
#   'background',
#   'death',
#   'updated',
#   'review',
#   'add',
#   '67',
#   '101',
#   '255',
#   '166'],
#  ['sex'],
#  ['burn', 'hate', 'sex', 'running'],
#  ['86', '29', '244', '57', '86', '29', '244', '57', '04', '21', '14', '2007'],
#  ['link', 'dead', 'formatted', 'plz', 'matter'],
#  ['reply',
#   'loser',
#   'defines',
#   'vietnam',
#   'asia',
#   'vietnam',
#   'french',
#   'shit',
#   'countries',
#   'culture',
#   'influenced',
#   'sea',
#   'chinese',
#   'proper',
#   'chinese',
#   'fringe',
#   'indigenous',
#   'tribes',
#   'admit',
#   'vietnamese',
#   'bunch',
#   'crap',
#   'people',
#   'east',
#   'asian',
#   'people',
#   'spoken',
#   'vietnam',
#   'integral',
#   'sea',
#   'dirty',
#   'speak',
#   'horrible',
#   'language',
#   'matter',
#   'crap',
#   'wikipedia',
#   'change',
#   'people',
#   'real'],
#  ['29',
#   'august',
#   '2006',
#   'wow',
#   'understand',
#   'crucial',
#   'change',
#   'content',
#   'community',
#   'caused',
#   'sourced',
#   'statement',
#   'inform',
#   'people',
#   'falls',
#   'seemingly',
#   'article',
#   'time',
#   'edit',
#   'criteria',
#   'determine',
#   'reverted',
#   'simply',
#   'removed',
#   'removal',
#   'unwarranted',
#   'insist',
#   'absence',
#   'statement',
#   'adding',
#   'factual',
#   'sourced',
#   'informative',
#   'assume',
#   'reason',
#   'remove',
#   'wiki',
#   'nazis',
#   'concerned',
#   'useless',
#   'edits',
#   'edit',
#   'carried',
#   'imho',
#   'useless',
#   'change'],
#  ['stupid', 'fuck', 'mother', 'cunt'],
#  ['john', 'house', 'talk'],
#  ['userbox',
#   'tabtab',
#   'tabtab',
#   'white',
#   'tabtab',
#   'info',
#   'user',
#   'faggot',
#   'tabtab',
#   'info',
#   'tabtab',
#   'border',
#   'black',
#   'tabtab',
#   'lgbt',
#   'wikipedians',
#   'tabtab',
#   'tabtab',
#   'tabtab',
#   'tabtab',
#   'template',
#   'automatically',
#   'user',
#   'lgbt'],
#  ['16', 'december', '2005', 'utc', 'talk', 'conspiracy', '16', '53'],
#  ['vandalize', 'edit', 'continue', 'blocked', 'editing'],
#  ['correct', 'dead', 'dead', 'emphasis', 'pov', 'adjective'],
#  ['fixed', 'pic', 'feels', 'voices'],
#  ['george',
#   'bush',
#   'approval',
#   'rating',
#   'graph',
#   'upload',
#   'wikimedia',
#   'wikipedia',
#   'commons',
#   '1',
#   'george',
#   'bush',
#   'approval',
#   'ratings',
#   'events',
#   'svg',
#   'circle',
#   'september',
#   'attacks',
#   'update',
#   'data',
#   'post',
#   '2005'],
#  ['edits', '200', '1000', 'counts'],
#  ['absolutely',
#   'word',
#   'misleading',
#   'structure',
#   'definition',
#   'space',
#   'structure',
#   'solid',
#   'space',
#   'wall'],
#  ['noticed',
#   'neutrality',
#   'article',
#   'disputed',
#   'light',
#   'post',
#   'invitation',
#   'discuss',
#   'neutrality',
#   'achieved',
#   'deleted',
#   'highly',
#   'relevant',
#   'bearing',
#   'mind',
#   'rule',
#   'wikipedia',
#   'time',
#   'truth',
#   'achieved'],
#  ['editors',
#   'care',
#   'explanations',
#   'reliable',
#   'published',
#   'sources',
#   'explain',
#   'dogs',
#   'cats',
#   'reception',
#   'provide',
#   'sources',
#   'edit',
#   'warring',
#   'sources',
#   'talk'],
#  ['moved', 'idea'],
#  ['sockpuppets', 'sockpuppet', 'accounts', 'including'],
#  ['films',
#   'named',
#   'variation',
#   'listed',
#   'wondering',
#   'sense',
#   'apologize',
#   'advance',
#   'individuals',
#   'sensitive',
#   'hear',
#   'truth'],
#  ['review',
#   'request',
#   'request',
#   'class',
#   'review',
#   'stuff',
#   'airlines',
#   'cheers'],
#  ['propose',
#   'article',
#   'mention',
#   'raising',
#   'mouth',
#   'pre',
#   'environment',
#   'suffice',
#   'american',
#   'raise',
#   'hear',
#   'bit',
#   'hear',
#   'english',
#   'people',
#   'difference',
#   'americans',
#   'tendency',
#   'raising',
#   'surprised',
#   'broad',
#   'accent',
#   'wikipedian',
#   'thinking'],
#  ['intent',
#   'behavior',
#   'opportunity',
#   'famous',
#   'persons',
#   'gay',
#   'life',
#   'received',
#   'perfectly',
#   'normal',
#   'generations',
#   'people',
#   'grow',
#   'exposed',
#   'strategy',
#   'increasingly',
#   'develop',
#   'homosexuality',
#   'universally',
#   'accepted',
#   'alternate',
#   'behavior',
#   'religion',
#   'race',
#   'nationality'],
#  ['article', 'notable', 'biography', 'criteria', 'set', 'wp', 'bio'],
#  ['link',
#   'wikipedia',
#   'link',
#   'article',
#   'word',
#   'appears',
#   'editor',
#   'appears',
#   'stalking',
#   'reverting',
#   'claims',
#   'read',
#   'policy',
#   'understand',
#   'disagree',
#   'word',
#   'linked',
#   'article',
#   'link',
#   'link',
#   'context',
#   'reader',
#   'wrong',
#   'link',
#   'objective',
#   'opinions',
#   '74',
#   '234',
#   '45',
#   '208'],
#  ['blatant',
#   'pov',
#   'pushing',
#   'guys',
#   'contribution',
#   'italian',
#   'history',
#   'article',
#   'unconstructive',
#   'modern',
#   'pov',
#   'history',
#   'article',
#   'history',
#   'heard',
#   'reason',
#   'people',
#   'pissed',
#   'wikipedia',
#   'life'],
#  ['reliable', 'sources', 'insert', 'personal', 'analysis', 'article', 'talk'],
#  ['relevance',
#   'article',
#   'wp',
#   'el',
#   'realise',
#   'links',
#   'deleted',
#   'agree',
#   'people',
#   'official',
#   'sites',
#   'delete',
#   'game'],
#  ['notice',
#   'depth',
# ...
#   'talk',
#   'improving',
#   'article',
#   'address',
#   'issues',
#   'raised',
#   'removing',
#   'deletion',
#   'notice',
#   'prevent',
#   'deletion',
#   'proposed',
#   'deletion',
#   'process',
#   'article',
#   'deleted',
#   'matches',
#   'speedy',
#   'deletion',
#   'criteria',
#   'articles',
#   'deletion',
#   'deleted',
#   'consensus',
#   'delete',
#   'reached'],
#  ['hmmm', 'remember', 'code'],
#  ['article', 'exists', 'pro'],
#  ['citation', 'looked', 'opinion'],
#  ['mentioned',
#   'article',
#   'based',
#   'worthless',
#   'cited',
#   'source',
#   'article',
#   'rest',
#   'gang',
#   'pro',
#   'communist',
#   'bias',
#   'bother',
#   'check',
#   'cite',
#   'reliable',
#   'historical',
#   'sources',
#   'subject',
#   'absurd',
#   'accusations',
#   'white',
#   'conspiracy',
#   'soviet',
#   'government',
#   'motivated',
#   'anti',
#   'semitic',
#   'racism',
#   'claims',
#   'based',
#   'question',
#   'communist',
#   'regime',
#   'major',
#   'regime',
#   'minor',
#   'justified',
#   'mere',
#   'aforementioned',
#   'published',
#   'admitted',
#   'socialist',
#   'party',
#   'definition',
#   'source',
#   'meet',
#   'wp',
#   'npov',
#   'wp',
#   'rs',
#   'sources',
#   'continue',
#   'wikipedia',
#   'articles',
#   'project',
#   '67',
#   '169',
#   '177',
#   '176'],
#  ['messages',
#   'talk',
#   'afd',
#   'placing',
#   'messages',
#   'users',
#   'talk',
#   'hope',
#   'support',
#   'unacceptable',
#   'practice',
#   'afd',
#   'process'],
#  ['trivia',
#   'advise',
#   'word',
#   'dictionary',
#   'jay',
#   'marriage',
#   'business',
#   'dynasty',
#   'noteworthy',
#   'article',
#   'linked',
#   'cheers'],
#  ['remind',
#   'english',
#   'language',
#   'wikipedia',
#   'edit',
#   'wikipedia',
#   'aggressive',
#   'attitude',
#   'names',
#   'easily',
#   'fixed',
#   'improvements',
#   'english',
#   'person',
#   'judge',
#   '81',
#   '178',
#   '252',
#   '102'],
#  ['speedy',
#   'deletion',
#   'david',
#   'fork',
#   'tag',
#   'david',
#   'fork',
#   'requesting',
#   'speedily',
#   'deleted',
#   'wikipedia',
#   'a1',
#   'criteria',
#   'speedy',
#   'deletion',
#   'short',
#   'article',
#   'providing',
#   'context',
#   'reader',
#   'wikipedia',
#   'stub',
#   'minimum',
#   'standards',
#   'short',
#   'articles',
#   'note',
#   'articles',
#   'notable',
#   'subjects',
#   'provide',
#   'references',
#   'reliable',
#   'sources',
#   'verify',
#   'content',
#   'notice',
#   'error',
#   'contest',
#   'deletion',
#   'adding',
#   'existing',
#   'speedy',
#   'deletion',
#   'db',
#   'tag',
#   'coupled',
#   'adding',
#   'note',
#   'talk',
#   'explaining',
#   'position',
#   'aware',
#   'tagged',
#   'speedy',
#   'deletion',
#   'article',
#   'meets',
#   'criterion',
#   'deleted',
#   'delay',
#   'remove',
#   'speedy',
#   'deletion',
#   'tag',
#   'hesitate',
#   'add',
#   'article',
#   'render',
#   'conformance',
#   'wikipedia',
#   'policies',
#   'guidelines'],
#  ['suggestion',
#   'editing',
#   'article',
#   'completely',
#   'wikipedia',
#   'guidelines',
#   'jayjg',
#   'slimvirgin',
#   'started',
#   'deleting',
#   'relevant',
#   'article',
#   'reverting',
#   'agree',
#   'article',
#   'reason',
#   'article',
#   'locked',
#   'agree',
#   'start',
#   'extremely',
#   'definition',
#   'statement',
#   'agree',
#   'definition',
#   'sort',
#   'word',
#   'agree',
#   'terrorism',
#   'definition',
#   'instance'],
#  ['speaking',
#   'knowing',
#   'talking',
#   'bout',
#   'original',
#   'comment',
#   'entry',
#   'constantly',
#   'vandalized',
#   'fans',
#   'written',
#   'month',
#   'dumb',
#   'ass',
#   'involved',
#   'started',
#   'peoples',
#   'track',
#   'believed',
#   'verse',
#   'contributed',
#   'deserve',
#   'synopsis',
#   'idiotic',
#   'comment',
#   'album',
#   'sales',
#   'excessive',
#   'unnecessary',
#   'belongs',
#   'artists',
#   'agrees',
#   'knock',
#   'living',
#   'shit',
#   'fan'],
#  ['talk', 'archives', '1', '2', '3', '4', '5', '6', '7'],
#  ['speedy',
#   'deletion',
#   'tag',
#   'requesting',
#   'speedily',
#   'deleted',
#   'wikipedia',
#   'criteria',
#   'speedy',
#   'deletion',
#   'article',
#   'appears',
#   'repost',
#   'material',
#   'deleted',
#   'deletion',
#   'debate',
#   'articles',
#   'deletion',
#   'criteria',
#   'article',
#   'identical',
#   'content',
#   'article',
#   'deleted',
#   'debate',
#   'content',
#   'address',
#   'reasons',
#   'material',
#   'deleted',
#   'deleted',
#   'time',
#   'notice',
#   'error',
#   'contest',
#   'deletion',
#   'adding',
#   'existing',
#   'speedy',
#   'deletion',
#   'db',
#   'tag',
#   'coupled',
#   'adding',
#   'note',
#   'article',
#   'talk',
#   'explaining',
#   'position',
#   'aware',
#   'tagged',
#   'speedy',
#   'deletion',
#   'article',
#   'meets',
#   'criterion',
#   'deleted',
#   'delay',
#   'remove',
#   'speedy',
#   'deletion',
#   'tag',
#   'hesitate',
#   'add',
#   'article',
#   'render',
#   'conformance',
#   'wikipedia',
#   'policies',
#   'guidelines',
#   'talk'],
#  ['natural', 'born', 'citizen', 'assume', 'cares'],
#  ['unblocked', 'time', 'fuck', 'luck', 'night'],
#  ['understand',
#   'position',
#   'perfectly',
#   'valid',
#   'creation',
#   'wikipedia',
#   'lack',
#   'historical',
#   'sources',
#   'english',
#   'language',
#   'tomorrow',
#   'explaining',
#   'position',
#   'accurate'],
#  ['cock', 'frank', 'pussy', 'fucking', 'hit'],
#  ['user', 'talk', 'constructive', 'edits', 'indef', 'block'],
#  ['accurate',
#   'deliberately',
#   'misleading',
#   'string',
#   'guitar',
#   'garbage',
#   'doubt',
#   'myspace',
#   'temporary',
#   'hidden',
#   'removed',
#   'google',
#   'search',
#   'listings',
#   'truth'],
#  ['determined',
#   'delete',
#   'inappropriate',
#   'completely',
#   'inappropriate',
#   'post',
#   'middle',
#   'sensitive',
#   'discussion',
#   'sole',
#   'talk',
#   'post',
#   'violate',
#   'conditions',
#   'arbitration',
#   'decision',
#   'affect',
#   'flow',
#   'discussion',
#   'response',
#   'ignore',
#   'removing',
#   'encourage',
#   'reaction',
#   'accuse',
#   'absurd',
#   'guidelines',
#   'violate',
#   'guideline',
#   'policies',
#   'heavy',
#   'handed',
#   'action',
#   'people',
#   'persist',
#   'edits',
#   'standing',
#   'convention',
#   'remove',
#   'users',
#   'posts',
#   'vandalism',
#   'reason',
#   'deleted'],
#  ['people',
#   'republic',
#   'china',
#   'carried',
#   'survey',
#   'wall',
#   'surprise',
#   'chinese',
#   'wall',
#   'exist',
#   'day',
#   'day',
#   'wall',
#   'add',
#   'details',
#   'government',
#   'survey'],
#  ['kindly', 'deleting', 'user', 'piss', 'people', 'wikipedia'],
#  ['jim',
#   'child',
#   'faggot',
#   'day',
#   'total',
#   'usual',
#   'extreme',
#   'hypocritical',
#   'arrogance',
#   'ethical',
#   'principles',
#   'claimed',
#   'rights',
#   'abuse',
#   'children',
#   'ethical',
#   'principles',
#   'save',
#   'life',
#   'roman',
#   'drop',
#   'dead',
#   'easier',
#   'kids',
#   'sake',
#   'word',
#   'write'],
#  ['read', 'changed', 'structure', 'separate', 'view', 'separate', 'details'],
#  ['bother', 'cheese', 'wine'],
#  ['fixed', 'link', '3', 'leave', 'report', 'administrators'],
#  ['told',
#   'deliberate',
#   'personal',
#   'attacks',
#   'belief',
#   'messages',
#   'interpreted',
#   'wrongly',
#   'faith',
#   'posting',
#   'mentioned'],
#  ['remove',
#   'content',
#   'explanation',
#   'edit',
#   'continue',
#   'blocked',
#   'editing',
#   'royal',
#   'court'],
#  ['deleted',
#   'american',
#   'criminal',
#   'category',
#   'incredible',
#   'article',
#   'lead',
#   'misguided',
#   'soul',
#   'american',
#   'criminal',
#   'category',
#   'discussion',
#   'category',
#   'talk',
#   'category',
#   'reading',
#   'category'],
#  ['template',
#   'fight',
#   'concept',
#   'art',
#   'bull',
#   'shit',
#   '86',
#   '166',
#   '250',
#   '11',
#   'waste'],
#  ['add',
#   'kansas',
#   'bear',
#   'mistake',
#   'calling',
#   'treaty',
#   'left',
#   'usual',
#   'post',
#   'regarded',
#   'treaty',
#   'treaty',
#   'private',
#   'treaty',
#   'france',
#   'military',
#   'alliance',
#   'recognition',
#   'changing',
#   'subject',
#   'statements',
#   'feel',
#   'posts',
#   'utterly',
#   'questionable',
#   'month',
#   'agreed',
#   'treaty',
#   'corrected',
#   'statement',
#   'regarded',
#   'treaty',
#   'childish',
#   'personal',
#   'attacks',
#   'sources',
#   'recognize',
#   'henry',
#   'king',
#   'france',
#   'treaty',
#   'posts',
#   'handle',
#   'recognised',
#   'henry',
#   'king',
#   'france',
#   'reverted',
#   'dual',
#   'article',
#   'ashamed',
#   'remarks',
#   'utterly',
#   'questionable',
#   'unsourced'],
#  ['1',
#   'usernames',
#   'vote',
#   'poll',
#   'idea',
#   'talking',
#   'usernames',
#   'voted',
#   'poll',
#   '2',
#   'vandal',
#   'vandalised',
#   'content',
#   'agree',
#   'vandalism',
#   'correct',
#   'discussion',
#   'debate',
#   'achieve',
#   '3',
#   'sockpuppet',
#   'person',
#   'wikipedia',
#   'sockpuppet',
#   'opinion',
#   'administrator'],
#  ['request',
#   'lawyer',
#   'nov',
#   '5',
#   'refused',
#   'request',
#   'allowed',
#   'father',
#   '138',
#   'denied',
#   'food',
#   'water',
#   'breaks',
#   'night',
#   'nov',
#   '5',
#   '6',
#   '151',
#   'murder',
#   'italy',
#   'additional',
#   'included',
#   'listing',
#   'tomorrow'],
#  ['suggestion',
#   'pretty',
#   'leading',
#   'sentence',
#   'rest',
#   'article',
#   'details',
#   'edit',
#   'suggestion'],
#  ['alex',
#   'article',
#   'edge',
#   'deleted',
#   'deletion',
#   'discussion',
#   'arguing',
#   'hope',
#   'keeping',
#   'article',
#   'online',
#   'spending',
#   'time',
#   'editing',
#   'talk',
#   'link',
#   'deletion',
#   'discussion',
#   'arguments'],
#  ['fu', 'ing'],
#  ['day',
#   'remember',
#   'laugh',
#   'ha',
#   'ha',
#   'ha',
#   'ha',
#   'ha',
#   'forget',
#   'incredible',
#   'power',
#   'powerful',
#   'imagine',
#   'close',
#   'conversation'],
#  ['noticed',
#   'table',
#   'approach',
#   'eye',
#   'game',
#   'central',
#   'game',
#   'update',
#   'table',
#   'table',
#   'class',
#   'age',
#   'iii',
#   'sort',
#   'falling'],
#  ['bin',
#   'time',
#   'time',
#   'mind',
#   'shit',
#   'sum',
#   'dead',
#   'alive',
#   'send',
#   'check',
#   'condition',
#   'led',
#   'bro',
#   'wall',
#   'dude',
#   'ain',
#   'gonna',
#   'bro',
#   'harm',
#   'ben',
#   'cut',
#   'sum',
#   'sleep',
#   'ta',
#   'dream',
#   'ta',
#   'wave',
#   'bro'],
#  ['missed', 'lifetime', 'chance', 'talk'],
#  ['henry', 'david', 'considered', 'vandalism', 'experiment', 'sandbox'],
#  ['source',
#   'biography',
#   'louis',
#   'louis',
#   'le',
#   'jean',
#   'contradictory',
#   'influences',
#   'french',
#   'government',
#   'prior',
#   'revolution',
#   'devoted',
#   'royal',
#   'family',
#   'note',
#   'province',
#   'washington',
#   'continental',
#   'army',
#   'truth',
#   'died',
#   'december',
#   '31',
#   'book',
#   'george',
#   'washington',
#   '1',
#   'george',
#   'washington',
#   'owned',
#   '33',
#   '000',
#   'land',
#   '2',
#   'washington',
#   'lived',
#   'york',
#   'preceding',
#   'unsigned',
#   'comment',
#   '71',
#   '230',
#   '187',
#   '220',
#   'wikipedia',
#   'add',
#   'link'],
#  ['textbook',
#   'material',
#   'ads',
#   'refer',
#   'controversy',
#   'schools',
#   'surrounding',
#   'series',
#   'called',
#   'contained',
#   'writings',
#   'parents',
#   'believed',
#   'featured',
#   'violence',
#   'authority',
#   'discussion',
#   'offending',
#   'pieces',
#   'called',
#   'tree',
#   'days',
#   'christmas',
#   'stuff',
#   'tree',
#   'stance',
#   'harry',
#   'potter'],
#  ['biographical',
#   'article',
#   'answer',
#   'discussion',
#   'town',
#   'born',
#   'schools',
#   'disagree',
#   'article',
#   'bit',
#   'expansion',
#   'articles',
#   'individuals',
#   'mentioned',
#   'living',
#   'admit',
#   'heard',
#   'names',
#   'judging',
#   'max',
#   'david',
#   'awards',
#   'industry',
#   'press',
#   'personal',
#   'opinion',
#   'technique'],
#  ['sort', 'criticism', 'praise', 'quotes', 'talk'],
#  ['haha',
#   'fine',
#   'allowed',
#   'guess',
#   'respect',
#   'borrowed',
#   'credit',
#   'feel',
#   'badly',
#   'feel',
#   'badly',
#   'haha',
#   'figure',
#   'nice',
#   'pick',
#   'fun',
#   'colors',
#   'day',
#   'happy'],
#  ['leave', 'told', 'leave', 'fuck', 'fucking', 'amusing', 'asshole', 'ban'],
#  ['voting',
#   'countries',
#   'populations',
#   'influenced',
#   'considerably',
#   'cited',
#   'reason',
#   'apparent',
#   'voting',
#   'countries',
#   'yugoslavia',
#   '91',
#   'crazy',
#   'countries',
#   'cultures',
#   'speak',
#   'languages',
#   'stars',
#   'croatia',
#   'popular',
#   'serbia',
#   'vice',
#   'people',
#   'countries',
#   'largest',
#   'proportion',
#   'countries',
#   'countries',
#   'explain',
#   'croatia',
#   'serbia',
#   'macedonia',
#   'serbia',
#   'conflict',
#   'speak',
#   'bosnian',
#   'serb',
#   'voting',
#   'croatian',
#   'serbian',
#   'song',
#   'unusual',
#   'bosnian',
#   'national',
#   'family',
#   'lived',
#   'serbia',
#   'history',
#   'mutual',
#   'votes',
#   'time',
#   'language'],
#  ['published', 'source', 'explain', 'published'],
#  ['vandalize', 'edit', 'continue', 'blocked', 'editing', '2009'],
#  ['24',
#   'august',
#   '2007',
#   'utc',
#   'wp',
#   'rs',
#   'di',
#   'claim',
#   'wp',
#   'rs',
#   'verifiable',
#   '103',
#   'original',
#   'agreed',
#   'di',
#   'published',
#   'interpretation',
#   'political',
#   'position',
#   'subsequent',
#   'political',
#   'purpose',
#   'taught',
#   'school',
#   'verifiable',
#   'record',
#   '103',
#   'original',
#   'called',
#   'evidence',
#   'scientific',
#   'theories',
#   'di',
#   'unverifiable',
#   'claim',
#   'agreement',
#   'support',
#   'interpretation',
#   'political',
#   'agenda',
#   'rules',
#   'wikipedia',
#   'rest',
#   'di',
#   'propaganda',
#   'utter',
#   'di',
#   'demonstrated',
#   'consent',
#   'original',
#   '103',
#   'individuals',
#   'view',
#   'wp',
#   'blp',
#   'harm',
#   'clause',
#   'claim',
#   'di',
#   'promoted',
#   'content',
#   'wp',
#   'blp',
#   '16',
#   '11'],
#  ['email',
#   'email',
#   'message',
#   'received',
#   'received',
#   'openly',
#   'threatening',
#   'email'],
#  ['intent', 'belongs', 'dan', 'article'],
#  ['discussion',
#   'steve',
#   'moore',
#   'credentials',
#   'aspect',
#   'article',
#   'knox',
#   'supporters',
#   'hurt',
#   'expressing',
#   'opinions',
#   'effectively',
#   'stated',
#   'decisions',
#   'italian',
#   'court',
#   'influenced',
#   'anger',
#   'anti',
#   'american',
#   'sentiment',
#   'evidence',
#   'experience',
#   'italy',
#   'qualifies',
#   'assessment',
#   'rs',
#   'statement',
#   'insult',
#   'italian',
#   'knox',
#   'supporters',
#   'wholly',
#   'concur',
#   'opinion',
#   'piece',
#   'article'],
#  ['water', 'animal'],
#  ['fear',
#   'correct',
#   'btw',
#   'died',
#   '1973',
#   'meant',
#   'praise',
#   'emphasis',
#   'judging',
#   'knowledge',
#   'anti',
#   'intellectual'],
#  ['mess', 'zealand', 'australia'],
#  ['omg', 'love', 'love', 'sun'],
#  ['removed', 'article'],
#  ['wikipedia',
#   'hope',
#   'stay',
#   'depth',
#   'read',
#   'pillars',
#   'wikipedia',
#   'simplified',
#   'title',
#   'articles',
#   'check',
#   'naming',
#   'conventions',
#   'formatting',
#   'visit',
#   'manual',
#   'style',
#   'wikipedia',
#   'faq',
#   'answer',
#   'check',
#   'village',
#   'pump',
#   'wikipedia',
#   'questions',
#   'reference',
#   'desk',
#   'questions',
#   'tutorial',
#   'policy',
#   'library',
#   'forget',
#   'visit',
#   'community',
#   'portal',
#   'questions',
#   'feel',
#   'post',
#   'user',
#   'talk',
#   'helpme',
#   'talk',
#   'shortly',
#   'tab',
#   'additional',
#   'tips',
#   'tabtab',
#   'extra',
#   'tips',
#   'pedia',
#   'play',
#   'wiki',
#   'skills',
#   'sandbox',
#   'tab',
#   'sign',
#   'tildes',
#   'add',
#   'add',
#   'user',
#   'log',
#   'tab',
#   'image',
#   'deleted',
#   'list',
#   'votes',
#   'deletion',
#   'votes',
#   'deleted',
#   'confused',
#   'grasp',
#   'wikipedia',
#   'skills',
#   'irc',
#   'client',
#   'mind',
#   'check',
#   'sounds',
#   'fun',
#   'editing',
#   'skills',
#   'bored',
#   'random',
#   'button',
#   'check',
#   'task',
#   'message',
#   'community',
#   'portal',
#   'happy',
#   'wiki',
#   'ing',
#   'talk',
#   'contribs',
#   'respond',
#   'message'],
#  ['common',
#   'knowledge',
#   'jews',
#   'descent',
#   'realize',
#   'ancestors',
#   'lost',
#   'tribes',
#   'israel',
#   'formed',
#   'precisely',
#   'reason',
#   'jewish',
#   'scholars',
#   'ben',
#   'ben',
#   'ali',
#   'ben',
#   'writings',
#   'editor'],
#  ['12',
#   'april',
#   '2006',
#   'utc',
#   'rewrite',
#   'expand',
#   'article',
#   'article',
#   'bad',
#   'article',
#   'template',
#   'william',
#   'edits',
#   'vote',
#   'content',
#   'matter',
#   'time',
#   'looked',
#   'article',
#   'link',
#   'choose',
#   'version',
#   'vote',
#   'purely',
#   'layout',
#   'including',
#   'template',
#   'spent',
#   'time',
#   'unfamiliar',
#   'article',
#   'statement',
#   'content',
#   '16',
#   '06'],
#  ['humour',
#   'ridiculous',
#   'situation',
#   'time',
#   'situation',
#   'person',
#   'insulted',
#   'attacking',
#   'cited',
#   'factual',
#   'contributions',
#   'actively',
#   'censoring',
#   'explanation',
#   'insulting',
#   'conduct',
#   'insult',
#   'worthy',
#   'time',
#   'individual',
#   'familiar',
#   'wikipedia',
#   'insult',
#   'rule',
#   'realized',
#   'wrong',
#   'harsh',
#   'wikipedia',
#   'edit',
#   'constructive',
#   'brought',
#   'knowledge',
#   'subject',
#   'topic',
#   'insulted',
#   'user',
#   'edit',
#   'summary',
#   'edit',
#   'linked',
#   'constitutes',
#   'insult'],
#  ['title', 'redirect', 'change', 'moment', 'links', 'bother'],
#  ...]

# %% [markdown]
# ## Word2Vec

# %%
# 事前準備したtextsを使ってWord2Vecの学習実施
model = word2vec.Word2Vec(texts, size=100,min_count=5,window=5,iter=100)

# %%
model.save("./w2v_model.model")

# %% [markdown]
# ### Find fimilar words

# %%
# 類似している単語を見る
similar_words = model.wv.most_similar(positive=["explanation"], topn=10)
for result in similar_words:
    print(result)
# Out:
# ('explain', 0.5744209289550781)
# ('justification', 0.5061910152435303)
# ('reasoning', 0.5009664297103882)
# ('rationale', 0.48656165599823)
# ('summary', 0.47709399461746216)
# ('lacking', 0.46698758006095886)
# ('explained', 0.4453938603401184)
# ('response', 0.43788477778434753)
# ('explanations', 0.42586082220077515)
# ('description', 0.4087681174278259)

# %% [markdown]
# ### Caliculate similaridy between words

# %%
# ２つの単語の類似度を計算。
w1 = "reasoning"
w2 = "justification"
similarity = model.wv.similarity(w1=w1, w2=w2)
print("Similarity of ", w1, " and ", w2, ": ", similarity)
# Out:
# Similarity of  reasoning  and  justification :  0.49161577
